# %%
import vaex
import pandas as pd
import numpy as np
import geopandas as gp
import folium
from shapely import Polygon
import contextily as cx
import h3

# %%
df_trips = vaex.open('data/trips/trips_prepared.hdf5')

# %%
# Method to get h3 polygons
def convert_hex_to_polygon(hex):
        polygon = None
        if hex:
               polygon = Polygon(h3.h3_to_geo_boundary(hex, geo_json=True))         
        return polygon

# %%
# Get GeoDataFrame with count for pickup or dropoff for every hexagon of the selected resolution
def getRidesHexagon(df, pickup, resolution):
    # Decide for Pickup or dropoff
    var = "dropoff"
    if pickup:
        var = "pickup"
    
    # Groupby count
    x = df.groupby(by=var+"_hex_" + str(resolution), progress=True).agg({ 'ts_start':'count' }).to_pandas_df()

    # Warum ist dieser Schritt Nötig? @Leo: Warum gibt es Fahrten ohne Hexagon Zuordnung?
    x = x[(x[var+"_hex_" + str(resolution)].notna()) & (x[var+"_hex_" + str(resolution)] != "None")]

    # Add Polygons
    x["geometry"] = x[var+"_hex_" + str(resolution)].apply(convert_hex_to_polygon)

    #Creating proper GeoDataFrame
    x = x.reset_index().set_index(var+"_hex_" + str(resolution)).rename(columns = {"ts_start": "count"}).drop(columns = ["index"])
    gdf = gp.GeoDataFrame(x, geometry='geometry', crs = "EPSG:4326")
    
    return gdf

# %%
def plotRidesHexagon(gdf, column, text):
    # Preperations for choropleth-plotting
    gdf.index.name = None
    gdf = gdf.reset_index()
    gjson = gdf.to_json()

    # Plotting with Folium
    m = folium.Map([41.88065, -87.62642], zoom_start=10,width=700,height=700)
    folium.Choropleth(
        geo_data=gjson,
        name="choropleth",
        data=gdf,
        columns=["index", column],  #Here we tell folium to get the county fips and plot new_cases_7days metric for each county
        key_on='feature.properties.index', #Here we grab the geometries/county boundaries from the geojson file using the key 'coty_code' which is the same as county fips
        fill_opacity=0.7,
        line_opacity=0.2,
        fill_color="YlGn",
        legend_name=text, #title of the legend
        line_color='black').add_to(m)
    return m

# %%
gdf = getRidesHexagon(df_trips, True, 7)
plotRidesHexagon(gdf, "count", "Rides with pickup location in hexgon")
# Out:
# groupby [########################################] 100.00% elapsed time  :     1.55s =  0.0m =  0.0h
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_2354f3ae03ea0c679b6b6b31723f5459 {
#                     position: relative;
#                     width: 700.0px;
#                     height: 700.0px;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/d3/3.5.5/d3.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_2354f3ae03ea0c679b6b6b31723f5459&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_2354f3ae03ea0c679b6b6b31723f5459 = L.map(
#                 &quot;map_2354f3ae03ea0c679b6b6b31723f5459&quot;,
#                 {
#                     center: [41.88065, -87.62642],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 10,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_720fc99be9ccb47d8becd06e7344dd12 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_2354f3ae03ea0c679b6b6b31723f5459);
#
#
#             var choropleth_09aadc4a96bbf1e75306daf7dcf64678 = L.featureGroup(
#                 {}
#             ).addTo(map_2354f3ae03ea0c679b6b6b31723f5459);
#
#
#         function geo_json_e74d5c33d3a7bd21c7d2703b03da641e_styler(feature) {
#             switch(feature.id) {
#                 case &quot;50&quot;:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;#78c679&quot;, &quot;fillOpacity&quot;: 0.7, &quot;opacity&quot;: 0.2, &quot;weight&quot;: 1};
#                 case &quot;58&quot;:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;#d9f0a3&quot;, &quot;fillOpacity&quot;: 0.7, &quot;opacity&quot;: 0.2, &quot;weight&quot;: 1};
#                 case &quot;75&quot;:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;#006837&quot;, &quot;fillOpacity&quot;: 0.7, &quot;opacity&quot;: 0.2, &quot;weight&quot;: 1};
#                 default:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;#ffffcc&quot;, &quot;fillOpacity&quot;: 0.7, &quot;opacity&quot;: 0.2, &quot;weight&quot;: 1};
#             }
#         }
#
#         function geo_json_e74d5c33d3a7bd21c7d2703b03da641e_onEachFeature(feature, layer) {
#             layer.on({
#             });
#         };
#         var geo_json_e74d5c33d3a7bd21c7d2703b03da641e = L.geoJson(null, {
#                 onEachFeature: geo_json_e74d5c33d3a7bd21c7d2703b03da641e_onEachFeature,
#
#                 style: geo_json_e74d5c33d3a7bd21c7d2703b03da641e_styler,
#         });
#
#         function geo_json_e74d5c33d3a7bd21c7d2703b03da641e_add (data) {
#             geo_json_e74d5c33d3a7bd21c7d2703b03da641e
#                 .addData(data)
#                 .addTo(choropleth_09aadc4a96bbf1e75306daf7dcf64678);
#         }
#             geo_json_e74d5c33d3a7bd21c7d2703b03da641e_add({&quot;features&quot;: [{&quot;geometry&quot;: {&quot;coordinates&quot;: [[[-87.75249479459073, 41.94687342940655], [-87.7652129365424, 41.938592103207704], [-87.76108070772123, 41.9264413389641], [-87.74423741886551, 41.92256977628124], [-87.73151926588986, 41.93084716338697], [-87.73564441086972, 41.94300005161201], [-87.75249479459073, 41.94687342940655]]], &quot;type&quot;: &quot;Polygon&quot;}, &quot;id&quot;: &quot;0&quot;, &quot;properties&quot;: {&quot;count&quot;: 1074, &quot;index&quot;: &quot;872664ca2ffffff&quot;}, &quot;type&quot;: &quot;Feature&quot;}, {&quot;geometry&quot;: {&quot;coordinates&quot;: [[[-87.682183101495, 41.7851293674406], [-87.69487158269276, 41.77687368187779], [-87.69077151729793, 41.76474210967957], [-87.67399001439686, 41.760864113671765], [-87.66130154233943, 41.7691158687078], [-87.6653945621452, 41.78124954962191], [-87.682183101495, 41.7851293674406]]], &quot;type&quot;: &quot;Polygon&quot;}, &quot;id&quot;: &quot;1&quot;, &quot;properties&quot;: {&quot;count&quot;: 1749, &quot;index&quot;: &quot;872664cd1ffffff&quot;}, &quot;type&quot;: &quot;Feature&quot;}, {&quot;geometry&quot;: {&quot;coordinates&quot;: [[[-87.69935218235355, 41.74435966478091], [-87.71202588150466, 41.736106974707745], [-87.70792510676493, 41.723982037598525], [-87.6911576614432, 41.72010768055518], [-87.67848396651723, 41.72835644256933], [-87.68257771079374, 41.74048348903096], [-87.69935218235355, 41.74435966478091]]], &quot;type&quot;: &quot;Polygon&quot;}, &quot;id&quot;: &quot;2&quot;, &quot;properties&quot;: {&quot;count&quot;: 9, &quot;index&quot;: &quot;872664cdaffffff&quot;}, &quot;type&quot;: &quot;Feature&quot;}, {&quot;geometry&quot;: {&quot;coordinates&quot;: [[[-87.90424336171452, 41.981623576878405], [-87.9169389761855, 41.97332310147526], [-87.91276527118177, 41.96117525189432], [-87.89590301982581, 41.95732573224688], [-87.8832073506073, 41.96562226802875], [-87.8873739855495, 41.97777226242878], [-87.90424336171452, 41.981623576878405]]], &quot;type&quot;: &quot;Polygon&quot;}, &quot;id&quot;: &quot;3&quot;, &

# %%
gdf = getRidesHexagon(df_trips, False, 7)
plotRidesHexagon(gdf, "count", "Rides with dropoff location in hexgon")
# Out:
# groupby [########################################] 100.00% elapsed time  :     1.43s =  0.0m =  0.0h
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_a8f08b710e39428e14bcdeee210b6ca6 {
#                     position: relative;
#                     width: 700.0px;
#                     height: 700.0px;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/d3/3.5.5/d3.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_a8f08b710e39428e14bcdeee210b6ca6&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_a8f08b710e39428e14bcdeee210b6ca6 = L.map(
#                 &quot;map_a8f08b710e39428e14bcdeee210b6ca6&quot;,
#                 {
#                     center: [41.88065, -87.62642],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 10,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_ad2df4b948380e0dc286998f264a7c08 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_a8f08b710e39428e14bcdeee210b6ca6);
#
#
#             var choropleth_8ea7162ac59a020680aeb2c40cd9bc79 = L.featureGroup(
#                 {}
#             ).addTo(map_a8f08b710e39428e14bcdeee210b6ca6);
#
#
#         function geo_json_e5d90a026fbcc59da9d9c37b2cf93591_styler(feature) {
#             switch(feature.id) {
#                 case &quot;51&quot;:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;#78c679&quot;, &quot;fillOpacity&quot;: 0.7, &quot;opacity&quot;: 0.2, &quot;weight&quot;: 1};
#                 case &quot;59&quot;:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;#d9f0a3&quot;, &quot;fillOpacity&quot;: 0.7, &quot;opacity&quot;: 0.2, &quot;weight&quot;: 1};
#                 case &quot;76&quot;:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;#006837&quot;, &quot;fillOpacity&quot;: 0.7, &quot;opacity&quot;: 0.2, &quot;weight&quot;: 1};
#                 default:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;#ffffcc&quot;, &quot;fillOpacity&quot;: 0.7, &quot;opacity&quot;: 0.2, &quot;weight&quot;: 1};
#             }
#         }
#
#         function geo_json_e5d90a026fbcc59da9d9c37b2cf93591_onEachFeature(feature, layer) {
#             layer.on({
#             });
#         };
#         var geo_json_e5d90a026fbcc59da9d9c37b2cf93591 = L.geoJson(null, {
#                 onEachFeature: geo_json_e5d90a026fbcc59da9d9c37b2cf93591_onEachFeature,
#
#                 style: geo_json_e5d90a026fbcc59da9d9c37b2cf93591_styler,
#         });
#
#         function geo_json_e5d90a026fbcc59da9d9c37b2cf93591_add (data) {
#             geo_json_e5d90a026fbcc59da9d9c37b2cf93591
#                 .addData(data)
#                 .addTo(choropleth_8ea7162ac59a020680aeb2c40cd9bc79);
#         }
#             geo_json_e5d90a026fbcc59da9d9c37b2cf93591_add({&quot;features&quot;: [{&quot;geometry&quot;: {&quot;coordinates&quot;: [[[-87.682183101495, 41.7851293674406], [-87.69487158269276, 41.77687368187779], [-87.69077151729793, 41.76474210967957], [-87.67399001439686, 41.760864113671765], [-87.66130154233943, 41.7691158687078], [-87.6653945621452, 41.78124954962191], [-87.682183101495, 41.7851293674406]]], &quot;type&quot;: &quot;Polygon&quot;}, &quot;id&quot;: &quot;0&quot;, &quot;properties&quot;: {&quot;count&quot;: 4076, &quot;index&quot;: &quot;872664cd1ffffff&quot;}, &quot;type&quot;: &quot;Feature&quot;}, {&quot;geometry&quot;: {&quot;coordinates&quot;: [[[-87.75249479459073, 41.94687342940655], [-87.7652129365424, 41.938592103207704], [-87.76108070772123, 41.9264413389641], [-87.74423741886551, 41.92256977628124], [-87.73151926588986, 41.93084716338697], [-87.73564441086972, 41.94300005161201], [-87.75249479459073, 41.94687342940655]]], &quot;type&quot;: &quot;Polygon&quot;}, &quot;id&quot;: &quot;1&quot;, &quot;properties&quot;: {&quot;count&quot;: 1804, &quot;index&quot;: &quot;872664ca2ffffff&quot;}, &quot;type&quot;: &quot;Feature&quot;}, {&quot;geometry&quot;: {&quot;coordinates&quot;: [[[-87.69935218235355, 41.74435966478091], [-87.71202588150466, 41.736106974707745], [-87.70792510676493, 41.723982037598525], [-87.6911576614432, 41.72010768055518], [-87.67848396651723, 41.72835644256933], [-87.68257771079374, 41.74048348903096], [-87.69935218235355, 41.74435966478091]]], &quot;type&quot;: &quot;Polygon&quot;}, &quot;id&quot;: &quot;2&quot;, &quot;properties&quot;: {&quot;count&quot;: 9, &quot;index&quot;: &quot;872664cdaffffff&quot;}, &quot;type&quot;: &quot;Feature&quot;}, {&quot;geometry&quot;: {&quot;coordinates&quot;: [[[-87.90424336171452, 41.981623576878405], [-87.9169389761855, 41.97332310147526], [-87.91276527118177, 41.96117525189432], [-87.89590301982581, 41.95732573224688], [-87.8832073506073, 41.96562226802875], [-87.8873739855495, 41.97777226242878], [-87.90424336171452, 41.981623576878405]]], &quot;type&quot;: &quot;Polygon&quot;}, &quot;id&quot;: &quot;3&quot;, &

# %%
gdf = getRidesHexagon(df_trips, True, 7)
gdf["logCount"] = np.log(gdf['count'])
plotRidesHexagon(gdf, "logCount", "Natural Logarithm of rides with pickup location in hexgon")
# Out:
# groupby [########################################] 100.00% elapsed time  :     1.50s =  0.0m =  0.0h
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_4d0dc45ab42453877d7a6a25bf76d7cc {
#                     position: relative;
#                     width: 700.0px;
#                     height: 700.0px;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/d3/3.5.5/d3.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_4d0dc45ab42453877d7a6a25bf76d7cc&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_4d0dc45ab42453877d7a6a25bf76d7cc = L.map(
#                 &quot;map_4d0dc45ab42453877d7a6a25bf76d7cc&quot;,
#                 {
#                     center: [41.88065, -87.62642],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 10,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_72868dddd8588237b1a0df1e9720258d = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_4d0dc45ab42453877d7a6a25bf76d7cc);
#
#
#             var choropleth_6e85079d82c4f4083fec4ca20d5445d6 = L.featureGroup(
#                 {}
#             ).addTo(map_4d0dc45ab42453877d7a6a25bf76d7cc);
#
#
#         function geo_json_2438e4d80a9b28aea778c0ee2afbcf90_styler(feature) {
#             switch(feature.id) {
#                 case &quot;2&quot;: case &quot;8&quot;: case &quot;10&quot;: case &quot;12&quot;: case &quot;25&quot;: case &quot;32&quot;: case &quot;34&quot;: case &quot;42&quot;: case &quot;43&quot;: case &quot;49&quot;: case &quot;52&quot;: case &quot;53&quot;: case &quot;54&quot;: case &quot;57&quot;: case &quot;60&quot;: case &quot;68&quot;: case &quot;115&quot;: case &quot;116&quot;: case &quot;121&quot;:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;#ffffcc&quot;, &quot;fillOpacity&quot;: 0.7, &quot;opacity&quot;: 0.2, &quot;weight&quot;: 1};
#                 case &quot;3&quot;: case &quot;44&quot;: case &quot;50&quot;: case &quot;58&quot;: case &quot;62&quot;: case &quot;64&quot;: case &quot;75&quot;: case &quot;114&quot;:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;#006837&quot;, &quot;fillOpacity&quot;: 0.7, &quot;opacity&quot;: 0.2, &quot;weight&quot;: 1};
#                 case &quot;5&quot;: case &quot;9&quot;: case &quot;20&quot;: case &quot;27&quot;: case &quot;30&quot;: case &quot;31&quot;: case &quot;33&quot;: case &quot;40&quot;: case &quot;41&quot;: case &quot;47&quot;: case &quot;48&quot;: case &quot;55&quot;: case &quot;67&quot;: case &quot;77&quot;: case &quot;78&quot;: case &quot;81&quot;: case &quot;82&quot;: case &quot;85&quot;: case &quot;87&quot;: case &quot;100&quot;: case &quot;101&quot;: case &quot;103&quot;: case &quot;104&quot;: case &quot;105&quot;: case &quot;107&quot;: case &quot;111&quot;: case &quot;113&quot;:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;#78c679&quot;, &quot;fillOpacity&quot;: 0.7, &quot;opacity&quot;: 0.2, &quot;weight&quot;: 1};
#                 case &quot;7&quot;: case &quot;15&quot;: case &quot;17&quot;: case &quot;18&quot;: case &quot;59&quot;: case &quot;63&quot;: case &quot;73&quot;: case &quot;74&quot;: case &quot;90&quot;: case &quot;92&quot;: case &quot;98&quot;: case &quot;99&quot;: case &quot;110&quot;: case &quot;118&quot;:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;#d9f0a3&quot;, &quot;fillOpacity&quot;: 0.7, &quot;opacity&quot;: 0.2, &quot;weight&quot;: 1};
#                 case &quot;16&quot;: case &quot;19&quot;: case &quot;22&quot;: case &quot;24&quot;: case &quot;26&quot;: case &quot;29&quot;: case &quot;37&quot;: case &quot;38&quot;: case &quot;39&quot;: case &quot;45&quot;: case &quot;51&quot;: case &quot;70&quot;: case &quot;76&quot;: case &quot;80&quot;: case &quot;93&quot;: case &quot;94&quot;: case &quot;96&quot;: case &quot;106&quot;: case &quot;108&quot;: case &quot;117&quot;: case &quot;119&quot;:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;#31a354&quot;, &quot;fillOpacity&quot;: 0.7, &quot;opacity&quot;: 0.2, &quot;weight&quot;: 1};
#                 default:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;#addd8e&quot;, &quot;fillOpacity&quot;: 0.7, &quot;opacity&quot;: 0.2, &quot;weight&quot;: 1};
#             }
#         }
#
#         function geo_json_2438e4d80a9b28aea778c0ee2afbcf90_onEachFeature(feature, layer) {
#             layer.on({
#             });
#         };
#         var geo_json_2438e4d80a9b28aea778c0ee2afbcf90 = L.geoJson(null, {
#                 onEachFeature: geo_json_2438e4d80a9b28aea778c0ee2afbcf90_onEachFeature,
#
#                 style: geo_json_2438e4d80a9b28aea778c0ee2afbcf90_styler,
#         });
#
#         function geo_json_2438e4d80a9b28aea778c0ee2afbcf90_add (data) {
#             geo_json_2438e4d80a9b28aea778c0ee2afbcf90

# %%
gdf = getRidesHexagon(df_trips, False, 7)
gdf["logCount"] = np.log(gdf['count'])
plotRidesHexagon(gdf, "logCount", "Natural Logarithm of rides with dropoff location in hexgon")
# Out:
# groupby [########################################] 100.00% elapsed time  :     1.49s =  0.0m =  0.0h
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_fd3fb45dcfba8742f4cf8bd6ba98fd4e {
#                     position: relative;
#                     width: 700.0px;
#                     height: 700.0px;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/d3/3.5.5/d3.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_fd3fb45dcfba8742f4cf8bd6ba98fd4e&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_fd3fb45dcfba8742f4cf8bd6ba98fd4e = L.map(
#                 &quot;map_fd3fb45dcfba8742f4cf8bd6ba98fd4e&quot;,
#                 {
#                     center: [41.88065, -87.62642],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 10,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_b4ef077642a8606db0c9a3c9cd6788f9 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_fd3fb45dcfba8742f4cf8bd6ba98fd4e);
#
#
#             var choropleth_d6d539a9144661baee068b6a8f73bb72 = L.featureGroup(
#                 {}
#             ).addTo(map_fd3fb45dcfba8742f4cf8bd6ba98fd4e);
#
#
#         function geo_json_5adf60e60847a660198269c951c64930_styler(feature) {
#             switch(feature.id) {
#                 case &quot;0&quot;: case &quot;1&quot;: case &quot;6&quot;: case &quot;11&quot;: case &quot;14&quot;: case &quot;17&quot;: case &quot;21&quot;: case &quot;23&quot;: case &quot;28&quot;: case &quot;36&quot;: case &quot;48&quot;: case &quot;57&quot;: case &quot;62&quot;: case &quot;64&quot;: case &quot;66&quot;: case &quot;70&quot;: case &quot;73&quot;: case &quot;85&quot;: case &quot;91&quot;: case &quot;92&quot;: case &quot;93&quot;: case &quot;96&quot;: case &quot;98&quot;: case &quot;113&quot;: case &quot;121&quot;:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;#addd8e&quot;, &quot;fillOpacity&quot;: 0.7, &quot;opacity&quot;: 0.2, &quot;weight&quot;: 1};
#                 case &quot;2&quot;: case &quot;8&quot;: case &quot;10&quot;: case &quot;12&quot;: case &quot;25&quot;: case &quot;32&quot;: case &quot;33&quot;: case &quot;35&quot;: case &quot;43&quot;: case &quot;44&quot;: case &quot;50&quot;: case &quot;54&quot;: case &quot;55&quot;: case &quot;58&quot;: case &quot;61&quot;: case &quot;69&quot;: case &quot;116&quot;: case &quot;117&quot;: case &quot;122&quot;:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;#ffffcc&quot;, &quot;fillOpacity&quot;: 0.7, &quot;opacity&quot;: 0.2, &quot;weight&quot;: 1};
#                 case &quot;3&quot;: case &quot;24&quot;: case &quot;45&quot;: case &quot;51&quot;: case &quot;59&quot;: case &quot;63&quot;: case &quot;65&quot;: case &quot;76&quot;: case &quot;115&quot;:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;#006837&quot;, &quot;fillOpacity&quot;: 0.7, &quot;opacity&quot;: 0.2, &quot;weight&quot;: 1};
#                 case &quot;7&quot;: case &quot;15&quot;: case &quot;18&quot;: case &quot;37&quot;: case &quot;53&quot;: case &quot;60&quot;: case &quot;74&quot;: case &quot;75&quot;: case &quot;89&quot;: case &quot;99&quot;: case &quot;100&quot;: case &quot;111&quot;: case &quot;119&quot;:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;#d9f0a3&quot;, &quot;fillOpacity&quot;: 0.7, &quot;opacity&quot;: 0.2, &quot;weight&quot;: 1};
#                 case &quot;9&quot;: case &quot;13&quot;: case &quot;16&quot;: case &quot;19&quot;: case &quot;22&quot;: case &quot;26&quot;: case &quot;27&quot;: case &quot;29&quot;: case &quot;38&quot;: case &quot;39&quot;: case &quot;40&quot;: case &quot;46&quot;: case &quot;52&quot;: case &quot;71&quot;: case &quot;77&quot;: case &quot;81&quot;: case &quot;88&quot;: case &quot;94&quot;: case &quot;95&quot;: case &quot;97&quot;: case &quot;107&quot;: case &quot;109&quot;: case &quot;114&quot;: case &quot;118&quot;: case &quot;120&quot;:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;#31a354&quot;, &quot;fillOpacity&quot;: 0.7, &quot;opacity&quot;: 0.2, &quot;weight&quot;: 1};
#                 default:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;#78c679&quot;, &quot;fillOpacity&quot;: 0.7, &quot;opacity&quot;: 0.2, &quot;weight&quot;: 1};
#             }
#         }
#
#         function geo_json_5adf60e60847a660198269c951c64930_onEachFeature(feature, layer) {
#             layer.on({
#             });
#         };
#         var geo_json_5adf60e60847a660198269c951c64930 = L.geoJson(null, {
#                 onEachFeature: geo_json_5adf60e60847a660198269c951c64930_onEachFeature,
#
#                 style: geo_json_5adf60e60847a660198269c951c64930_styler,
#         });
#
#         function geo_json_5adf60e60847a660198269c951c64930_add (data) {
#             geo_json_5adf60e6

# %%
gdf = getRidesHexagon(df_trips, True, 7)
gdf["logCount"] = np.log2(gdf['count'])
plotRidesHexagon(gdf, "logCount", "Log2 of count of rides with pickup location in hexgon")
# Out:
# groupby [########################################] 100.00% elapsed time  :     1.46s =  0.0m =  0.0h
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_4457ba2465916487c01b02366d824ff7 {
#                     position: relative;
#                     width: 700.0px;
#                     height: 700.0px;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/d3/3.5.5/d3.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_4457ba2465916487c01b02366d824ff7&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_4457ba2465916487c01b02366d824ff7 = L.map(
#                 &quot;map_4457ba2465916487c01b02366d824ff7&quot;,
#                 {
#                     center: [41.88065, -87.62642],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 10,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_00fe21c27fa5452a8cec03844677e371 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_4457ba2465916487c01b02366d824ff7);
#
#
#             var choropleth_955b703803ec4955f9a626f4bd8c0454 = L.featureGroup(
#                 {}
#             ).addTo(map_4457ba2465916487c01b02366d824ff7);
#
#
#         function geo_json_8495973921d258da3f688f9c3cad3227_styler(feature) {
#             switch(feature.id) {
#                 case &quot;2&quot;: case &quot;8&quot;: case &quot;10&quot;: case &quot;12&quot;: case &quot;25&quot;: case &quot;32&quot;: case &quot;34&quot;: case &quot;42&quot;: case &quot;43&quot;: case &quot;49&quot;: case &quot;52&quot;: case &quot;53&quot;: case &quot;54&quot;: case &quot;57&quot;: case &quot;60&quot;: case &quot;68&quot;: case &quot;115&quot;: case &quot;116&quot;: case &quot;121&quot;:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;#ffffcc&quot;, &quot;fillOpacity&quot;: 0.7, &quot;opacity&quot;: 0.2, &quot;weight&quot;: 1};
#                 case &quot;3&quot;: case &quot;44&quot;: case &quot;50&quot;: case &quot;58&quot;: case &quot;62&quot;: case &quot;64&quot;: case &quot;75&quot;: case &quot;114&quot;:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;#006837&quot;, &quot;fillOpacity&quot;: 0.7, &quot;opacity&quot;: 0.2, &quot;weight&quot;: 1};
#                 case &quot;5&quot;: case &quot;9&quot;: case &quot;20&quot;: case &quot;27&quot;: case &quot;30&quot;: case &quot;31&quot;: case &quot;33&quot;: case &quot;40&quot;: case &quot;41&quot;: case &quot;46&quot;: case &quot;48&quot;: case &quot;55&quot;: case &quot;67&quot;: case &quot;77&quot;: case &quot;78&quot;: case &quot;81&quot;: case &quot;82&quot;: case &quot;85&quot;: case &quot;87&quot;: case &quot;100&quot;: case &quot;101&quot;: case &quot;103&quot;: case &quot;104&quot;: case &quot;105&quot;: case &quot;107&quot;: case &quot;112&quot;: case &quot;113&quot;:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;#78c679&quot;, &quot;fillOpacity&quot;: 0.7, &quot;opacity&quot;: 0.2, &quot;weight&quot;: 1};
#                 case &quot;7&quot;: case &quot;15&quot;: case &quot;17&quot;: case &quot;18&quot;: case &quot;59&quot;: case &quot;63&quot;: case &quot;73&quot;: case &quot;74&quot;: case &quot;90&quot;: case &quot;92&quot;: case &quot;98&quot;: case &quot;99&quot;: case &quot;110&quot;: case &quot;118&quot;:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;#d9f0a3&quot;, &quot;fillOpacity&quot;: 0.7, &quot;opacity&quot;: 0.2, &quot;weight&quot;: 1};
#                 case &quot;16&quot;: case &quot;19&quot;: case &quot;22&quot;: case &quot;24&quot;: case &quot;26&quot;: case &quot;29&quot;: case &quot;37&quot;: case &quot;38&quot;: case &quot;39&quot;: case &quot;45&quot;: case &quot;51&quot;: case &quot;70&quot;: case &quot;76&quot;: case &quot;80&quot;: case &quot;93&quot;: case &quot;94&quot;: case &quot;96&quot;: case &quot;106&quot;: case &quot;108&quot;: case &quot;117&quot;: case &quot;119&quot;:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;#31a354&quot;, &quot;fillOpacity&quot;: 0.7, &quot;opacity&quot;: 0.2, &quot;weight&quot;: 1};
#                 default:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;#addd8e&quot;, &quot;fillOpacity&quot;: 0.7, &quot;opacity&quot;: 0.2, &quot;weight&quot;: 1};
#             }
#         }
#
#         function geo_json_8495973921d258da3f688f9c3cad3227_onEachFeature(feature, layer) {
#             layer.on({
#             });
#         };
#         var geo_json_8495973921d258da3f688f9c3cad3227 = L.geoJson(null, {
#                 onEachFeature: geo_json_8495973921d258da3f688f9c3cad3227_onEachFeature,
#
#                 style: geo_json_8495973921d258da3f688f9c3cad3227_styler,
#         });
#
#         function geo_json_8495973921d258da3f688f9c3cad3227_add (data) {
#             geo_json_8495973921d258da3f688f9c3cad3227

# %%
gdf = getRidesHexagon(df_trips, False, 7)
gdf["logCount"] = np.log2(gdf['count'])
plotRidesHexagon(gdf, "logCount", "Log2 of count of rides with dropoff location in hexgon")
# Out:
# groupby [########################################] 100.00% elapsed time  :     1.50s =  0.0m =  0.0h
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_5ae8347da5b5fc71898476738e13366c {
#                     position: relative;
#                     width: 700.0px;
#                     height: 700.0px;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/d3/3.5.5/d3.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_5ae8347da5b5fc71898476738e13366c&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_5ae8347da5b5fc71898476738e13366c = L.map(
#                 &quot;map_5ae8347da5b5fc71898476738e13366c&quot;,
#                 {
#                     center: [41.88065, -87.62642],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 10,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_58bb1e53ed7d427890692b8fcb054428 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_5ae8347da5b5fc71898476738e13366c);
#
#
#             var choropleth_403d3680db88c8666cb0739fd863ff94 = L.featureGroup(
#                 {}
#             ).addTo(map_5ae8347da5b5fc71898476738e13366c);
#
#
#         function geo_json_6b4fd9f1a50ae87fe443f9488296989d_styler(feature) {
#             switch(feature.id) {
#                 case &quot;0&quot;: case &quot;1&quot;: case &quot;6&quot;: case &quot;11&quot;: case &quot;14&quot;: case &quot;17&quot;: case &quot;21&quot;: case &quot;23&quot;: case &quot;28&quot;: case &quot;36&quot;: case &quot;48&quot;: case &quot;57&quot;: case &quot;62&quot;: case &quot;64&quot;: case &quot;66&quot;: case &quot;70&quot;: case &quot;73&quot;: case &quot;85&quot;: case &quot;90&quot;: case &quot;92&quot;: case &quot;93&quot;: case &quot;96&quot;: case &quot;98&quot;: case &quot;113&quot;: case &quot;121&quot;:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;#addd8e&quot;, &quot;fillOpacity&quot;: 0.7, &quot;opacity&quot;: 0.2, &quot;weight&quot;: 1};
#                 case &quot;2&quot;: case &quot;7&quot;: case &quot;10&quot;: case &quot;12&quot;: case &quot;25&quot;: case &quot;32&quot;: case &quot;33&quot;: case &quot;35&quot;: case &quot;43&quot;: case &quot;44&quot;: case &quot;50&quot;: case &quot;54&quot;: case &quot;55&quot;: case &quot;58&quot;: case &quot;61&quot;: case &quot;69&quot;: case &quot;116&quot;: case &quot;117&quot;: case &quot;122&quot;:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;#ffffcc&quot;, &quot;fillOpacity&quot;: 0.7, &quot;opacity&quot;: 0.2, &quot;weight&quot;: 1};
#                 case &quot;3&quot;: case &quot;24&quot;: case &quot;45&quot;: case &quot;51&quot;: case &quot;59&quot;: case &quot;63&quot;: case &quot;65&quot;: case &quot;76&quot;: case &quot;115&quot;:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;#006837&quot;, &quot;fillOpacity&quot;: 0.7, &quot;opacity&quot;: 0.2, &quot;weight&quot;: 1};
#                 case &quot;8&quot;: case &quot;15&quot;: case &quot;18&quot;: case &quot;37&quot;: case &quot;53&quot;: case &quot;60&quot;: case &quot;74&quot;: case &quot;75&quot;: case &quot;91&quot;: case &quot;99&quot;: case &quot;100&quot;: case &quot;111&quot;: case &quot;119&quot;:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;#d9f0a3&quot;, &quot;fillOpacity&quot;: 0.7, &quot;opacity&quot;: 0.2, &quot;weight&quot;: 1};
#                 case &quot;9&quot;: case &quot;13&quot;: case &quot;16&quot;: case &quot;19&quot;: case &quot;22&quot;: case &quot;26&quot;: case &quot;27&quot;: case &quot;29&quot;: case &quot;38&quot;: case &quot;39&quot;: case &quot;40&quot;: case &quot;46&quot;: case &quot;52&quot;: case &quot;71&quot;: case &quot;77&quot;: case &quot;83&quot;: case &quot;88&quot;: case &quot;94&quot;: case &quot;95&quot;: case &quot;97&quot;: case &quot;108&quot;: case &quot;109&quot;: case &quot;114&quot;: case &quot;118&quot;: case &quot;120&quot;:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;#31a354&quot;, &quot;fillOpacity&quot;: 0.7, &quot;opacity&quot;: 0.2, &quot;weight&quot;: 1};
#                 default:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;#78c679&quot;, &quot;fillOpacity&quot;: 0.7, &quot;opacity&quot;: 0.2, &quot;weight&quot;: 1};
#             }
#         }
#
#         function geo_json_6b4fd9f1a50ae87fe443f9488296989d_onEachFeature(feature, layer) {
#             layer.on({
#             });
#         };
#         var geo_json_6b4fd9f1a50ae87fe443f9488296989d = L.geoJson(null, {
#                 onEachFeature: geo_json_6b4fd9f1a50ae87fe443f9488296989d_onEachFeature,
#
#                 style: geo_json_6b4fd9f1a50ae87fe443f9488296989d_styler,
#         });
#
#         function geo_json_6b4fd9f1a50ae87fe443f9488296989d_add (data) {
#             geo_json_6b4fd9f1

# %%
gdf = getRidesHexagon(df_trips, False, 8)
plotRidesHexagon(gdf, "count", "count of rides with dropoff location in hexgon")
# Out:
# groupby [########################################] 100.00% elapsed time  :     1.57s =  0.0m =  0.0h
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_d6a2051eca7d1514c7895a8c99c00afb {
#                     position: relative;
#                     width: 700.0px;
#                     height: 700.0px;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/d3/3.5.5/d3.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_d6a2051eca7d1514c7895a8c99c00afb&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_d6a2051eca7d1514c7895a8c99c00afb = L.map(
#                 &quot;map_d6a2051eca7d1514c7895a8c99c00afb&quot;,
#                 {
#                     center: [41.88065, -87.62642],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 10,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_6b0154416c3e8587e76aeafc6a1b4f34 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_d6a2051eca7d1514c7895a8c99c00afb);
#
#
#             var choropleth_d2b20ba80956bdea97bb7547f366518c = L.featureGroup(
#                 {}
#             ).addTo(map_d6a2051eca7d1514c7895a8c99c00afb);
#
#
#         function geo_json_7149a98c9e25d99fed5bd314da84d143_styler(feature) {
#             switch(feature.id) {
#                 case &quot;32&quot;:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;#78c679&quot;, &quot;fillOpacity&quot;: 0.7, &quot;opacity&quot;: 0.2, &quot;weight&quot;: 1};
#                 case &quot;33&quot;: case &quot;128&quot;: case &quot;227&quot;: case &quot;267&quot;: case &quot;310&quot;: case &quot;409&quot;: case &quot;485&quot;:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;#d9f0a3&quot;, &quot;fillOpacity&quot;: 0.7, &quot;opacity&quot;: 0.2, &quot;weight&quot;: 1};
#                 case &quot;97&quot;: case &quot;140&quot;: case &quot;286&quot;:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;#addd8e&quot;, &quot;fillOpacity&quot;: 0.7, &quot;opacity&quot;: 0.2, &quot;weight&quot;: 1};
#                 case &quot;153&quot;: case &quot;219&quot;:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;#31a354&quot;, &quot;fillOpacity&quot;: 0.7, &quot;opacity&quot;: 0.2, &quot;weight&quot;: 1};
#                 case &quot;427&quot;:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;#006837&quot;, &quot;fillOpacity&quot;: 0.7, &quot;opacity&quot;: 0.2, &quot;weight&quot;: 1};
#                 default:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;#ffffcc&quot;, &quot;fillOpacity&quot;: 0.7, &quot;opacity&quot;: 0.2, &quot;weight&quot;: 1};
#             }
#         }
#
#         function geo_json_7149a98c9e25d99fed5bd314da84d143_onEachFeature(feature, layer) {
#             layer.on({
#             });
#         };
#         var geo_json_7149a98c9e25d99fed5bd314da84d143 = L.geoJson(null, {
#                 onEachFeature: geo_json_7149a98c9e25d99fed5bd314da84d143_onEachFeature,
#
#                 style: geo_json_7149a98c9e25d99fed5bd314da84d143_styler,
#         });
#
#         function geo_json_7149a98c9e25d99fed5bd314da84d143_add (data) {
#             geo_json_7149a98c9e25d99fed5bd314da84d143
#                 .addData(data)
#                 .addTo(choropleth_d2b20ba80956bdea97bb7547f366518c);
#         }
#             geo_json_7149a98c9e25d99fed5bd314da84d143_add({&quot;features&quot;: [{&quot;geometry&quot;: {&quot;coordinates&quot;: [[[-87.75345892665608, 41.89749155016896], [-87.75949394761369, 41.895679937203994], [-87.76012945912849, 41.891027562751255], [-87.75473110530814, 41.888186856282076], [-87.74869680501348, 41.88999801158316], [-87.748060137908, 41.89465033096467], [-87.75345892665608, 41.89749155016896]]], &quot;type&quot;: &quot;Polygon&quot;}, &quot;id&quot;: &quot;0&quot;, &quot;properties&quot;: {&quot;count&quot;: 31198, &quot;index&quot;: &quot;882664c80bfffff&quot;}, &quot;type&quot;: &quot;Feature&quot;}, {&quot;geometry&quot;: {&quot;coordinates&quot;: [[[-87.7335437076854, 41.74746052059352], [-87.73956024808456, 41.74565429823796], [-87.74019573313312, 41.74101043313846], [-87.7348158258643, 41.73817284592468], [-87.72880000213603, 41.7399786119792], [-87.7281633690373, 41.744622421496175], [-87.7335437076854, 41.74746052059352]]], &quot;type&quot;: &quot;Polygon&quot;}, &quot;id&quot;: &quot;1&quot;, &quot;properties&quot;: {&quot;count&quot;: 7, &quot;index&quot;: &quot;882664528bfffff&quot;}, &quot;type&quot;: &quot;Feature&quot;}, {&quot;geometry&quot;: {&quot;coordinates&quot;: [[[-87.7410482581392, 41.94584321661722], [-87.7470902756205, 41.94403081350185], [-87.74772772320502, 41.93937570329951], [-87.74232431131355, 41.93653305147893], [-87.73628301642758, 41.938344996728745], [-87.73564441086972, 41.94300005161201], [-87

# %%
gdf = getRidesHexagon(df_trips, False, 8)
gdf["logCount"] = np.log2(gdf['count'])
plotRidesHexagon(gdf, "logCount", "Log2of count of rides with dropoff location in hexgon")
# Out:
# groupby [########################################] 100.00% elapsed time  :     1.45s =  0.0m =  0.0h
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_32c546661d7bad59a2fdbe3cf931c7f6 {
#                     position: relative;
#                     width: 700.0px;
#                     height: 700.0px;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/d3/3.5.5/d3.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_32c546661d7bad59a2fdbe3cf931c7f6&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_32c546661d7bad59a2fdbe3cf931c7f6 = L.map(
#                 &quot;map_32c546661d7bad59a2fdbe3cf931c7f6&quot;,
#                 {
#                     center: [41.88065, -87.62642],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 10,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_778a6faf8eaf939e29676c01baae8345 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_32c546661d7bad59a2fdbe3cf931c7f6);
#
#
#             var choropleth_69b992f88f5f51b471b2602fba2ddcf0 = L.featureGroup(
#                 {}
#             ).addTo(map_32c546661d7bad59a2fdbe3cf931c7f6);
#
#
#         function geo_json_5946b37568de00933370b2cc7a69742f_styler(feature) {
#             switch(feature.id) {
#                 case &quot;0&quot;: case &quot;11&quot;: case &quot;12&quot;: case &quot;13&quot;: case &quot;22&quot;: case &quot;27&quot;: case &quot;34&quot;: case &quot;36&quot;: case &quot;42&quot;: case &quot;43&quot;: case &quot;47&quot;: case &quot;48&quot;: case &quot;52&quot;: case &quot;56&quot;: case &quot;68&quot;: case &quot;70&quot;: case &quot;71&quot;: case &quot;75&quot;: case &quot;76&quot;: case &quot;87&quot;: case &quot;91&quot;: case &quot;106&quot;: case &quot;111&quot;: case &quot;112&quot;: case &quot;124&quot;: case &quot;128&quot;: case &quot;132&quot;: case &quot;150&quot;: case &quot;163&quot;: case &quot;169&quot;: case &quot;170&quot;: case &quot;175&quot;: case &quot;181&quot;: case &quot;187&quot;: case &quot;188&quot;: case &quot;190&quot;: case &quot;193&quot;: case &quot;200&quot;: case &quot;201&quot;: case &quot;206&quot;: case &quot;220&quot;: case &quot;221&quot;: case &quot;222&quot;: case &quot;242&quot;: case &quot;243&quot;: case &quot;251&quot;: case &quot;256&quot;: case &quot;264&quot;: case &quot;278&quot;: case &quot;283&quot;: case &quot;293&quot;: case &quot;300&quot;: case &quot;305&quot;: case &quot;311&quot;: case &quot;326&quot;: case &quot;327&quot;: case &quot;328&quot;: case &quot;339&quot;: case &quot;349&quot;: case &quot;363&quot;: case &quot;372&quot;: case &quot;387&quot;: case &quot;389&quot;: case &quot;390&quot;: case &quot;395&quot;: case &quot;402&quot;: case &quot;417&quot;: case &quot;423&quot;: case &quot;428&quot;: case &quot;431&quot;: case &quot;434&quot;: case &quot;443&quot;: case &quot;444&quot;: case &quot;445&quot;: case &quot;450&quot;: case &quot;459&quot;: case &quot;465&quot;: case &quot;477&quot;: case &quot;478&quot;: case &quot;489&quot;: case &quot;498&quot;:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;#31a354&quot;, &quot;fillOpacity&quot;: 0.7, &quot;opacity&quot;: 0.2, &quot;weight&quot;: 1};
#                 case &quot;1&quot;: case &quot;9&quot;: case &quot;14&quot;: case &quot;23&quot;: case &quot;28&quot;: case &quot;38&quot;: case &quot;44&quot;: case &quot;49&quot;: case &quot;63&quot;: case &quot;73&quot;: case &quot;100&quot;: case &quot;101&quot;: case &quot;109&quot;: case &quot;113&quot;: case &quot;114&quot;: case &quot;115&quot;: case &quot;129&quot;: case &quot;134&quot;: case &quot;141&quot;: case &quot;143&quot;: case &quot;144&quot;: case &quot;145&quot;: case &quot;155&quot;: case &quot;156&quot;: case &quot;157&quot;: case &quot;198&quot;: case &quot;202&quot;: case &quot;214&quot;: case &quot;215&quot;: case &quot;230&quot;: case &quot;241&quot;: case &quot;245&quot;: case &quot;246&quot;: case &quot;254&quot;: case &quot;257&quot;: case &quot;265&quot;: case &quot;270&quot;: case &quot;276&quot;: case &quot;287&quot;: case &quot;288&quot;: case &quot;307&quot;: case &quot;316&quot;: case &quot;324&quot;: case &quot;332&quot;: case &quot;340&quot;: case &quot;347&quot;: case &quot;348&quot;: case &quot;355&quot;: case &quot;359&quot;: case &quot;381&quot;: case &quot;384&quot;: case &quot;404&quot;: case &quot;405&quot;: case &quot;418&quot;: case &quot;420&quot;: case &quot;433&quot;: case &quot;439&quot;: case &quot;446&quot;: case &quot;451&quot;: case &quot;456&quot;: case &quot;460&quot;: case &quot;467&quot;: case &quot;468&quot;: case &quot;472&quot;: case &quot;481&quot;: case &quot;486&quot;: case &quot;501&quot;:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;#addd8e&quot;, &quot;fillOpacity&quot;: 0.7, &quot;opacity&quot;: 0.2, &quot;weight&quot;: 1};
#                 case &quot;3&quot;: case &quot;8&quot;: cas

# %% [markdown]
# ### Offene Fragen
#
# - Warum gibt es für manche Rides None Werte in den Hexogon Spalten, heißt kein Hexgon für die Start oder Dropoff Location? Wenn es eine Dropoff Location gibt, warum kann es dann sein, dass es kein Hexogon zugeteilt bekommt?
# - Warum zwei verschiedene "None" Werte? (Einmal als None und einmal als "None")
#
# -
# -
#
# - Ist es richtig, dass in manchen Hexagons keine Rides gestartet sind?
