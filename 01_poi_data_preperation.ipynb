# %%
#Importing the important libraries
import pandas as pd
import geopandas as gp
# Folium for plotting maps
import folium
# For Spatial Discretization
import h3
from shapely import Polygon

# %%
# TBD
# Eigentlich ist der meiste Preperation Kram von POI aktuell in der load_poi Datei, sollte vielleicht hier rüber gezogen werden
# Hier ist eigentlich gerade nur die Spatial Discretization drin

# %%
df = pd.read_pickle("data/poi/poi.pickle")

# %%
df
# Out:
#                     amenity  \
# osmid
# 258490031           parking
# 269449042  parking_entrance
# 269450074  parking_entrance
# 269688947          post_box
# 270863340  parking_entrance
# ...                     ...
# 13621412                NaN
# 13621413                NaN
# 13621414                NaN
# 15910906                NaN
# 15910907                NaN
#
#                                                     geometry name  \
# osmid
# 258490031                         POINT (-87.64385 41.95123)  NaN
# 269449042                         POINT (-87.61506 41.85869)  NaN
# 269450074                         POINT (-87.58421 41.79174)  NaN
# 269688947                         POINT (-87.77220 42.00407)  NaN
# 270863340                         POINT (-87.61564 41.86421)  NaN
# ...                                                      ...  ...
# 13621412   POLYGON ((-87.66859 41.91735, -87.66895 41.917...  NaN
# 13621413   POLYGON ((-87.66793 41.91671, -87.66797 41.916...  NaN
# 13621414   POLYGON ((-87.66801 41.91728, -87.66800 41.917...  NaN
# 15910906   POLYGON ((-87.62624 41.87979, -87.62623 41.879...  NaN
# 15910907   POLYGON ((-87.62610 41.87984, -87.62610 41.880...  NaN
#
#                    category   latitude  longitude public_transport wheelchair
# osmid
# 258490031           parking -87.643847  41.951227              NaN        NaN
# 269449042           parking -87.615058  41.858689              NaN        NaN
# 269450074           parking -87.584208  41.791742              NaN        NaN
# 269688947             other -87.772198  42.004073              NaN        NaN
# 270863340           parking -87.615638  41.864208              NaN        NaN
# ...                     ...        ...        ...              ...        ...
# 13621412   public_transport -87.668448  41.917203         platform        NaN
# 13621413   public_transport -87.668182  41.917215         platform        NaN
# 13621414   public_transport -87.668066  41.917277         platform        NaN
# 15910906   public_transport -87.626201  41.879543         platform         no
# 15910907   public_transport -87.626064  41.879567         platform         no
#
# [38493 rows x 8 columns]

# %%
def convert_to_hex_id (row, res):
    hex_id = h3.geo_to_h3(row["latitude"], row["longitude"], res)
    return hex_id if hex_id != "0" else None

def convert_hex_to_polygon(hex):
        polygon = None
        if hex:
               polygon = Polygon(h3.h3_to_geo_boundary(hex, geo_json=True))         
        return polygon

# %%
# Creating Hex_ID Columns
df['hex_7']  = df.apply(convert_to_hex_id, res=7, axis=1)
df['hex_8']  = df.apply(convert_to_hex_id, res=8, axis=1)
df['hex_9']  = df.apply(convert_to_hex_id, res=9, axis=1)

# %%
# Creating Polygon Columns
df['pol_7']  = df['hex_7'].apply(convert_hex_to_polygon)
df['pol_8']  = df['hex_8'].apply(convert_hex_to_polygon) 
df['pol_9']  = df['hex_9'].apply(convert_hex_to_polygon)

# %%
df
# Out:
#                     amenity  \
# osmid
# 258490031           parking
# 269449042  parking_entrance
# 269450074  parking_entrance
# 269688947          post_box
# 270863340  parking_entrance
# ...                     ...
# 13621412                NaN
# 13621413                NaN
# 13621414                NaN
# 15910906                NaN
# 15910907                NaN
#
#                                                     geometry name  \
# osmid
# 258490031                         POINT (-87.64385 41.95123)  NaN
# 269449042                         POINT (-87.61506 41.85869)  NaN
# 269450074                         POINT (-87.58421 41.79174)  NaN
# 269688947                         POINT (-87.77220 42.00407)  NaN
# 270863340                         POINT (-87.61564 41.86421)  NaN
# ...                                                      ...  ...
# 13621412   POLYGON ((-87.66859 41.91735, -87.66895 41.917...  NaN
# 13621413   POLYGON ((-87.66793 41.91671, -87.66797 41.916...  NaN
# 13621414   POLYGON ((-87.66801 41.91728, -87.66800 41.917...  NaN
# 15910906   POLYGON ((-87.62624 41.87979, -87.62623 41.879...  NaN
# 15910907   POLYGON ((-87.62610 41.87984, -87.62610 41.880...  NaN
#
#                    category   latitude  longitude public_transport wheelchair  \
# osmid
# 258490031           parking -87.643847  41.951227              NaN        NaN
# 269449042           parking -87.615058  41.858689              NaN        NaN
# 269450074           parking -87.584208  41.791742              NaN        NaN
# 269688947             other -87.772198  42.004073              NaN        NaN
# 270863340           parking -87.615638  41.864208              NaN        NaN
# ...                     ...        ...        ...              ...        ...
# 13621412   public_transport -87.668448  41.917203         platform        NaN
# 13621413   public_transport -87.668182  41.917215         platform        NaN
# 13621414   public_transport -87.668066  41.917277         platform        NaN
# 15910906   public_transport -87.626201  41.879543         platform         no
# 15910907   public_transport -87.626064  41.879567         platform         no
#
#                      hex_7            hex_8            hex_9  \
# osmid
# 258490031  87f162cb3ffffff  88f162cb33fffff  89f162cb327ffff
# 269449042  87f162c82ffffff  88f162c825fffff  89f162c824bffff
# 269450074  87f162c9effffff  88f162c9ebfffff  89f162c9ea3ffff
# 269688947  87f162d82ffffff  88f162d827fffff  89f162d8263ffff
# 270863340  87f162c82ffffff  88f162c825fffff  89f162c824bffff
# ...                    ...              ...              ...
# 13621412   87f162cb1ffffff  88f162cb1dfffff  89f162cb1cbffff
# 13621413   87f162cb1ffffff  88f162cb1dfffff  89f162cb1cbffff
# 13621414   87f162cb1ffffff  88f162cb1dfffff  89f162cb1cbffff
# 15910906   87f162c95ffffff  88f162c953fffff  89f162c95afffff
# 15910907   87f162c95ffffff  88f162c953fffff  89f162c9537ffff
#
#                                                        pol_7  \
# osmid
# 258490031  POLYGON ((42.45485372632763 -87.65035618674197...
# 269449042  POLYGON ((41.90478740264824 -87.61759884955146...
# 269450074  POLYGON ((42.2926579683956 -87.58077569543251,...
# 269688947  POLYGON ((42.27702556927856 -87.78002300251185...
# 270863340  POLYGON ((41.90478740264824 -87.61759884955146...
# ...                                                      ...
# 13621412   POLYGON ((42.00587118320927 -87.66401976054641...
# 13621413   POLYGON ((42.00587118320927 -87.66401976054641...
# 13621414   POLYGON ((42.00587118320927 -87.66401976054641...
# 15910906   POLYGON ((42.399734125549884 -87.6271656517192...
# 15910907   POLYGON ((42.399734125549884 -87.6271656517192...
#
#                                                        pol_8  \
# osmid
# 258490031  POLYGON ((42.10473061920236 -87.64687129557504...
# 269449042  POLYGON ((41.90478740264824 -87.61759884955146...
# 269450074  POLYGON ((41.90442199612573 -87.58581635171623...
# 269688947  POLYGON ((42.11771620187541 -87.77398492992451...
# 270863340  POLYGON ((41.90478740264824 -87.61759884955146...
# ...                                                      ...
# 13621412   POLYGON ((41.95589462839159 -87.67259151561268...
# 13621413   POLYGON ((41.95589462839159 -87.67259151561268...
# 13621414   POLYGON ((41.95589462839159 -87.67259151561268...
# 15910906   POLYGON ((42.05309820751771 -87.62366577778347...
# 15910907   POLYGON ((42.05309820751771 -87.62366577778347...
#
#                                                        pol_9
# osmid
# 258490031  POLYGON ((41.96206295307917 -87.64412639467749...
# 269449042  POLYGON ((41.89771730558743 -87.614282664738, ...
# 269450074  POLYGON ((41.83495793074247 -87.58443463135715...
# 269688947  POLYGON ((42.042266734983315 -87.7726167178765...
# 270863340  POLYGON ((41.89771730558743 -87.614282664738, ...
# ...                                                      ...
# 13621412   POLYGON ((41.94858549156742 -87.66927583530232...
# 13621413   POLYGON ((41.94858549156742 -87.66927583530232...
# 13621414   POLYGON ((41.94858549156742 -87.66927583530232...
# 15910906   POLYGON ((41.92611599449193 -87.6275470835168,...
# 15910907   POLYGON ((41.9189866649551 -87.62423105911492,...
#
# [38493 rows x 14 columns]

# %%
df.to_pickle("data/poi/poi_prepared.pickle")
