# %% [markdown]
# ### 5. Smart Charging Using Reinforcement Learning:
# **Original Exercise:** <br>
# Consider an electric taxi driver who can charge her vehicle at home. To simplify the problem, we assume that the vehicle always arrives at home at 2 p.m. and leaves the garage at 4 p.m. each day. We want to design an intelligent charging system (an automated agent). Therefore, instead of a flat charging rate, the charging agent adjusts the charging power every 15 minutes, which is bounded between 0 kW and the highest rate (e.g., 22 kW). Also, the vehicle's battery has a capacity that cannot be exceeded. After leaving the garage, the taxi needs enough energy to complete its working day. The energy demand is a stochastic value following a normal distribution (you should choose the parameters, e.g., 𝜇= 30 kWh, 𝜎 = 5 kWh) and must be generated exactly when the driver wants to leave. The agent’s goal is to avoid running out of energy (you should consider a very high penalty for running out of energy) and to minimize the recharging cost. The recharging cost follows an exponential function of the power (i.e., ![image.png](attachment:image.png)), where 𝛼𝑡 is the time coefficient and p is the charging rate.
#
# The task is to create the environment (a very simple discrete event simulation) that receives the agent's decisions and returns the reward. In addition, you must define a Markov decision process, including states, actions, and reward function, and solve it using a reinforcement learning algorithm (e.g., deep q-network) to find optimal charging policies. To allow the use of discrete action methods, you can consider only limited charging options such as zero, low, medium, high.
#
#
# **In Bulletpoints:**
# - Problem description:
#     - An electric taxi driver can charge her vehicle at home between 2 p.m. and 4 p.m. each day
#     - The charging agent adjusts the charging power every 15 minutes within a range of 0 kW to 22 kW
#     - The vehicle's battery has a limited capacity that cannot be exceeded
#     - The taxi needs enough energy to complete its working day, which is a random value following a normal distribution (e.g., 𝜇= 30 kWh, 𝜎 = 5 kWh)
#     - The agent’s goal is to avoid running out of energy (with a very high penalty) and to minimize the recharging cost, which is an exponential function of the power (i.e., ![image.png](attachment:image.png)), where 𝛼𝑡 is the time coefficient and p is the charging rate
# - Task description:
#     - Create the environment that simulates the charging process and the energy demand, and returns the reward to the agent based on its actions
#     - Define a Markov decision process, including states, actions, and reward function, that models the problem
#     - Solve the Markov decision process using a reinforcement learning algorithm (e.g., deep q-network) to find optimal charging policies
#     - Consider only discrete action methods, such as zero, low, medium, high, for the charging power

# %%
### Imports
#Basic
import numpy as np
import random
import math
# Gym
from gym import Env
from gym.spaces import Box, Discrete
# Keras
from keras.models import Sequential
from keras.layers import Dense, Flatten
from keras.optimizers import Adam
# Keras RL
from rl.agents import DQNAgent
from rl.agents import SARSAAgent
from rl.policy import BoltzmannQPolicy
from rl.memory import SequentialMemory

# %% [markdown]
# ## Simple Environment for Testing

# %%
### Simple environment without probability for testing
class SimpleEnvironment(Env):
    def __init__(self):
        #Possible Actions for charging zero, low, medium to high
        self.action_space = Discrete(4)
        #Vehicle's battery: 69KWh; Timeframe 2p.m. to 4p.m.: 8x 15 minute intervals
        self.battery_limit = 69
        self.observation_space = np.array([Box(low=np.array([0]), high = np.array([self.battery_limit])), Box(low=np.array([0]), high = np.array([8]))])
        # Starting at 2p.m.: 0 (going to 3:45p.m.: 7)
        self.time = 0
        self.time_delta =  15/60
        # 20 KWh loaded battery at initialization
        self.battery = 20
        # our state consisting of battery status and time
        self.state = np.array([self.battery, self.time])


    def step(self, action):
        # Setting loading interval +1/8 /--> +15/120 minutes
        self.time += 1
        self.state[1] = self.time

        # Seting new battery state
        #zero
        load = 0
        if action == 2:
            #low
            load += 7 * self.time_delta
            # loading until max capacity 
            if self.battery + load > self.battery_limit:
                diff = self.battery_limit - self.battery
                load = diff / self.time_delta
        if action == 3:
            #medium
           load += 14 * self.time_delta
            # loading until max capacity 
           if self.battery + load > self.battery_limit:
                diff = self.battery_limit - self.battery
                load = diff / self.time_delta
        if action == 4:
            #high
            load += 22 * self.time_delta
            # loading until max capacity 
            if self.battery + load > self.battery_limit:
                diff = self.battery_limit - self.battery
                load = diff / self.time_delta
        # load multiplied by 15 min to get the 
        self.battery += load
        self.state[0] = self.battery

        # Simple cost function
        reward = (1/self.time)*load*(-1)

        
        print("time:" + str(self.time) + " |load:" + str(load) + " |reward:" + str(round(reward, 2)))

        #Checking if 2 Hours are done
        if self.time >= 8:
            # Static Demand
            kwh_needed = 30
            print("|needed:" + str(round(kwh_needed, 2))+" |battery:" + str(round(self.battery, 2)))
            # The agent’s goal is to avoid running out of energy (with a very high penalty) 
            if kwh_needed > self.battery:
                reward -= 25
            done = True
        else:
            done = False

        info = {}

        # Returning the step information
        return self.state, reward, done, info
    
    def reset(self):
        # Starting at 2p.m.: 0 (going to 3:45p.m.: 7)
        self.time = 0
        # 20 KWh loaded battery at initialization
        self.battery = 20
        # our state consisting of battery status and time
        self.state = np.array([self.battery, self.time])
        return self.state

# %%
simpleEnv = SimpleEnvironment()

# %%
# Some random examples
episodes = 2
for episode in range(1, episodes+1):
    print("__ Day " + str(episode) + " ___")
    state = simpleEnv.reset()
    done = False
    score = 0 
    while not done:
        action = simpleEnv.action_space.sample()
        n_state, reward, done, info = simpleEnv.step(action)
        score+=reward
    print('--> Score:{}'.format(round(score, 2)))
# Out:
# __ Day 1 ___
# time:1 |load:0 |reward:-0.0
# time:2 |load:0 |reward:-0.0
# time:3 |load:3.5 |reward:-1.17
# time:4 |load:0 |reward:-0.0
# time:5 |load:3.5 |reward:-0.7
# time:6 |load:0 |reward:-0.0
# time:7 |load:0 |reward:-0.0
# time:8 |load:3.5 |reward:-0.44
# |needed:30 |battery:30.5
# --> Score:-2.3
# __ Day 2 ___
# time:1 |load:1.75 |reward:-1.75
# time:2 |load:1.75 |reward:-0.88
# time:3 |load:1.75 |reward:-0.58
# time:4 |load:1.75 |reward:-0.44
# time:5 |load:0 |reward:-0.0
# time:6 |load:3.5 |reward:-0.58
# time:7 |load:0 |reward:-0.0
# time:8 |load:1.75 |reward:-0.22
# |needed:30 |battery:32.25
# --> Score:-4.45

# %%
# Destilling Information from hour model
states = simpleEnv.observation_space.shape
actions = simpleEnv.action_space.n
print("Actions: " + str(actions) + " | States: " + str(states))
# Out:
# Actions: 4 | States: (2,)

# %%
# Defining our model
model = Sequential()    
model.add(Flatten(input_shape=(1,2)))
model.add(Dense(8, activation='relu'))
model.add(Dense(4, activation='relu'))
model.add(Dense(actions, activation='linear'))
model.summary()
# Out:
# Model: "sequential_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  flatten_2 (Flatten)         (None, 2)                 0
#
#  dense_8 (Dense)             (None, 8)                 24
#
#  dense_9 (Dense)             (None, 4)                 36
#
#  dense_10 (Dense)            (None, 4)                 20
#
# =================================================================
# Total params: 80
# Trainable params: 80
# Non-trainable params: 0
# _________________________________________________________________

# %%
# Defining and training of Deep Q-Network Agent
policy = BoltzmannQPolicy()
memory = SequentialMemory(limit=100, window_length=1)
dqn = DQNAgent(model=model, memory=memory, policy=policy, nb_actions=actions, nb_steps_warmup=8*100, target_model_update=1e-2)
dqn.compile(Adam(learning_rate=0.01), metrics=['mae'])
dqn.fit(simpleEnv, nb_steps=40000, visualize=False, verbose=1)
# Out:
# Training for 40000 steps ...
# Interval 1 (0 steps performed)
# time:1 |load:0 |reward:-0.0
#     1/10000 [..............................] - ETA: 17:30 - reward: 0.0000e+00time:2 |load:0 |reward:-0.0
# time:3 |load:0 |reward:-0.0
# time:4 |load:0 |reward:-0.0
# time:5 |load:0 |reward:-0.0
# time:6 |load:0 |reward:-0.0
# time:7 |load:0 |reward:-0.0
# time:8 |load:0 |reward:-0.0
# |needed:30 |battery:20
# time:1 |load:0 |reward:-0.0
# time:2 |load:0 |reward:-0.0
# time:3 |load:0 |reward:-0.0
# time:4 |load:0 |reward:-0.0
# time:5 |load:0 |reward:-0.0
# time:6 |load:0 |reward:-0.0
# time:7 |load:0 |reward:-0.0
# time:8 |load:0 |reward:-0.0
# |needed:30 |battery:20
# time:1 |load:0 |reward:-0.0
# time:2 |load:0 |reward:-0.0
# time:3 |load:0 |reward:-0.0
# time:4 |load:0 |reward:-0.0
# time:5 |load:0 |reward:-0.0
# time:6 |load:0 |reward:-0.0
# time:7 |load:0 |reward:-0.0
# time:8 |load:0 |reward:-0.0
# |needed:30 |battery:20
# time:1 |load:0 |reward:-0.0
# time:2 |load:0 |reward:-0.0
# time:3 |load:0 |reward:-0.0
# time:4 |load:0 |reward:-0.0
# time:5 |load:0 |reward:-0.0
# time:6 |load:0 |reward:-0.0
# time:7 |load:0 |reward:-0.0
# time:8 |load:0 |reward:-0.0
# |needed:30 |battery:20
# time:1 |load:0 |reward:-0.0
# time:2 |load:0 |reward:-0.0
# time:3 |load:0 |reward:-0.0
# time:4 |load:0 |reward:-0.0
# time:5 |load:0 |reward:-0.0
# time:6 |load:0 |reward:-0.0
# time:7 |load:0 |reward:-0.0
# time:8 |load:0 |reward:-0.0
# |needed:30 |battery:20
# time:1 |load:0 |reward:-0.0
# time:2 |load:0 |reward:-0.0
# time:3 |load:0 |reward:-0.0
# time:4 |load:0 |reward:-0.0
# time:5 |load:0 |reward:-0.0
# time:6 |load:0 |reward:-0.0
# time:7 |load:0 |reward:-0.0
# time:8 |load:0 |reward:-0.0
# |needed:30 |battery:20
# time:1 |load:0 |reward:-0.0
#    49/10000 [..............................] - ETA: 10s - reward: -3.0612     time:2 |load:0 |reward:-0.0
# time:3 |load:0 |reward:-0.0
# time:4 |load:0 |reward:-0.0
# time:5 |load:0 |reward:-0.0
# time:6 |load:0 |reward:-0.0
# time:7 |load:0 |reward:-0.0
# time:8 |load:0 |reward:-0.0
# |needed:30 |battery:20
# time:1 |load:0 |reward:-0.0
# time:2 |load:0 |reward:-0.0
# time:3 |load:0 |reward:-0.0
# time:4 |load:0 |reward:-0.0
# time:5 |load:0 |reward:-0.0
# time:6 |load:0 |reward:-0.0
# time:7 |load:0 |reward:-0.0
# time:8 |load:0 |reward:-0.0
# |needed:30 |battery:20
# time:1 |load:0 |reward:-0.0
# time:2 |load:0 |reward:-0.0
# time:3 |load:0 |reward:-0.0
# time:4 |load:0 |reward:-0.0
# time:5 |load:0 |reward:-0.0
# time:6 |load:0 |reward:-0.0
# time:7 |load:0 |reward:-0.0
# time:8 |load:0 |reward:-0.0
# |needed:30 |battery:20
# time:1 |load:0 |reward:-0.0
# time:2 |load:0 |reward:-0.0
# time:3 |load:0 |reward:-0.0
# time:4 |load:0 |reward:-0.0
# time:5 |load:0 |reward:-0.0
# time:6 |load:0 |reward:-0.0
# time:7 |load:0 |reward:-0.0
# time:8 |load:0 |reward:-0.0
# |needed:30 |battery:20
# time:1 |load:0 |reward:-0.0
# time:2 |load:0 |reward:-0.0
# time:3 |load:0 |reward:-0.0
# time:4 |load:0 |reward:-0.0
# time:5 |load:0 |reward:-0.0
# time:6 |load:0 |reward:-0.0
# time:7 |load:0 |reward:-0.0
# time:8 |load:0 |reward:-0.0
# |needed:30 |battery:20
# time:1 |load:0 |reward:-0.0
# time:2 |load:0 |reward:-0.0
# time:3 |load:0 |reward:-0.0
# time:4 |load:0 |reward:-0.0
# time:5 |load:0 |reward:-0.0
# time:6 |load:0 |reward:-0.0
# time:7 |load:0 |reward:-0.0
# time:8 |load:0 |reward:-0.0
# |needed:30 |battery:20
#    96/10000 [..............................] - ETA: 10s - reward: -3.1250
# c:\Users\NickPC\.virtualenvs\AAA_2023-67gSWIjI\lib\site-packages\keras\engine\training_v1.py:2359: UserWarning: `Model.state_updates` will be removed in a future version. This property should not be used in TensorFlow 2.0, as `updates` are applied automatically.
#   updates=self.state_updates,
# time:1 |load:0 |reward:-0.0
# time:2 |load:0 |reward:-0.0
# time:3 |load:0 |reward:-0.0
# time:4 |load:0 |reward:-0.0
# time:5 |load:0 |reward:-0.0
# time:6 |load:0 |reward:-0.0
# time:7 |load:0 |reward:-0.0
# time:8 |load:0 |reward:-0.0
# |needed:30 |battery:20
# time:1 |load:0 |reward:-0.0
# time:2 |load:0 |reward:-0.0
# time:3 |load:0 |reward:-0.0
# time:4 |load:0 |reward:-0.0
# time:5 |load:0 |reward:-0.0
# time:6 |load:0 |reward:-0.0
# time:7 |load:0 |reward:-0.0
# time:8 |load:0 |reward:-0.0
# |needed:30 |battery:20
# time:1 |load:0 |reward:-0.0
# time:2 |load:0 |reward:-0.0
# time:3 |load:0 |reward:-0.0
# time:4 |load:0 |reward:-0.0
# time:5 |load:0 |reward:-0.0
# time:6 |load:0 |reward:-0.0
# time:7 |load:0 |reward:-0.0
# time:8 |load:0 |reward:-0.0
# |needed:30 |battery:20
# time:1 |load:0 |reward:-0.0
# time:2 |load:0 |reward:-0.0
# time:3 |load:0 |reward:-0.0
# time:4 |load:0 |reward:-0.0
# time:5 |load:0 |reward:-0.0
# time:6 |load:0 |reward:-0.0
# time:7 |load:0 |reward:-0.0
# time:8 |load:0 |reward:-0.0
# |needed:30 |battery:20
# time:1 |load:0 |reward:-0.0
# time:2 |load:0 |reward:-0.0
# time:3 |load:0 |reward:-0.0
# time:4 |load:0 |reward:-0.0
# time:5 |load:0 |reward:-0.0
# time:6 |load:0 |reward:-0.0
#   134/10000 [..............................] - ETA: 11s - reward: -2.9851time:7 |load:0 |reward:-0.0
# time:8 |load:0 |reward:-0.0
# |needed:30 |battery:20
# time:1 |load:0 |reward:-0.0
# time:2 |load:0 |reward:-0.0
# time:3 |load:0 |reward:-0.0
# time:4 |load:0 |reward:-0.0
# time:5 |load:0 |reward:-0.0
# time:6 |load:0 |reward:-0.0
# time:7 |load:0 |reward:-0.0
# time:8 |load:0 |reward:-0.0
# |needed:30 |battery:20
# time:1 |load:0 |reward:-0.0
# time:2 |load:0 |reward:-0.0
# time:3 |load:0 |reward:-0.0
# time:4 |load:0 |reward:-0.0
# time:5 |load:0 |reward:-0.0
# time:6 |load:0 |reward:-0.0
# time:7 |load:0 |reward:-0.0
# time:8 |load:0 |reward:-0.0
# |needed:30 |battery:20
# time:1 |load:0 |reward:-0.0
# time:2 |load:0 |reward:-0.0
# time:3 |load:0 |reward:-0.0
# time:4 |load:0 |reward:-0.0
# time:5 |load:0 |reward:-0.0
# time:6 |load:0 |reward:-0.0
# time:7 |load:0 |reward:-0.0
# time:8 |load:0 |reward:-0.0
# |needed:30 |battery:20
# time:1 |load:0 |reward:-0.0
# time:2 |load:0 |reward:-0.0
# time:3 |load:0 |reward:-0.0
# time:4 |load:0 |reward:-0.0
# time:5 |load:0 |reward:-0.0
# time:6 |load:0 |reward:-0.0
# time:7 |load:0 |reward:-0.0
# time:8 |load:0 |reward:-0.0
# |needed:30 |battery:20
# time:1 |load:0 |reward:-0.0
# time:2 |load:0 |reward:-0.0
# time:3 |load:0 |reward:-0.0
# time:4 |load:0 |reward:-0.0
# time:5 |load:0 |reward:-0.0
#   173/10000 [..............................] - ETA: 11s - reward: -3.0347time:6 |load:0 |reward:-0.0
# time:7 |load:0 |reward:-0.0
# time:8 |load:0 |reward:-0.0
# |needed:30 |battery:20
# time:1 |load:0 |reward:-0.0
# time:2 |load:0 |reward:-0.0
# time:3 |load:0 |reward:-0.0
# time:4 |load:0 |reward:-0.0
# time:5 |load:0 |reward:-0.0
# time:6 |load:0 |reward:-0.0
# time:7 |load:0 |reward:-0.0
# time:8 |load:0 |reward:-0.0
# |needed:30 |battery:20
# time:1 |load:0 |reward:-0.0
# time:2 |load:0 |reward:-0.0
# time:3 |load:0 |reward:-0.0
# time:4 |load:0 |reward:-0.0
# time:5 |load:0 |reward:-0.0
# time:6 |load:0 |reward:-0.0
# time:7 |load:0 |reward:-0.0
# time:8 |load:0 |reward:-0.0
# |needed:30 |battery:20
# time:1 |load:0 |reward:-0.0
# time:2 |load:0 |reward:-0.0
# time:3 |load:0 |reward:-0.0
# time:4 |load:0 |reward:-0.0
# time:5 |load:0 |reward:-0.0
# time:6 |load:0 |reward:-0.0
# time:7 |load:0 |reward:-0.0
# time:8 |load:0 |reward:-0.0
# |needed:30 |battery:20
# time:1 |load:0 |reward:-0.0
# time:2 |load:0 |reward:-0.0
# time:3 |load:0 |reward:-0.0
# time:4 |load:0 |reward:-0.0
# time:5 |load:0 |reward:-0.0
# time:6 |load:0 |reward:-0.0
# time:7 |load:0 |reward:-0.0
# time:8 |load:0 |reward:-0.0
# |needed:30 |battery:20
# time:1 |load:0 |reward:-0.0
# time:2 |load:0 |reward:-0.0
# time:3 |load:0 |reward:-0.0
# time:4 |load:0 |reward:-0.0
# time:5 |load:0 |reward:-0.0
# time:6 |load:0 |reward:-0.0
# time:7 |load:0 |reward:-0.0
# time:8 |load:0 |reward:-0.0
# |needed:30 |battery:20
# time:1 |load:0 |reward:-0.0
# time:2 |load:0 |reward:-0.0
# time:3 |load:0 |reward:-0.0
# time:4 |load:0 |reward:-0.0
# time:5 |load:0 |reward:-0.0
# time:6 |load:0 |reward:-0.0
# time:7 |load:0 |reward:-0.0
# time:8 |load:0 |reward:-0.0
# |needed:30 |battery:20
# time:1 |load:0 |reward:-0.0
# time:2 |load:0 |reward:-0.0
# time:3 |load:0 |reward:-0.0
# time:4 |load:0 |reward:-0.0
# time:5 |load:0 |reward:-0.0
# time:6 |load:0 |reward:-0.0
#   230/10000 [..............................] - ETA: 10s - reward: -3.0435time:7 |load:0 |reward:-0.0
# time:8 |load:0 |reward:-0.0
# |needed:30 |battery:20
# time:1 |load:0 |reward:-0.0
# time:2 |load:0 |reward:-0.0
# time:3 |load:0 |reward:-0.0
# time:4 |load:0 |reward:-0.0
# time:5 |load:0 |reward:-0.0
# time:6 |load:0 |reward:-0.0
# time:7 |load:0 |reward:-0.0
# time:8 |load:0 |reward:-0.0
# |needed:30 |battery:20
# time:1 |load:0 |reward:-0.0
# time:2 |load:0 |reward:-0.0
# time:3 |load:0 |reward:-0.0
# time:4 |load:0 |reward:-0.0
# time:5 |load:0 |reward:-0.0
# time:6 |load:0 |reward:-0.0
# time:7 |load:0 |reward:-0.0
# time:8 |load:0 |reward:-0.0
# |needed:30 |battery:20
# time:1 |load:0 |reward:-0.0
# time:2 |load:0 |reward:-0.0
# time:3 |load:0 |reward:-0.0
# time:4 |load:0 |reward:-0.0
# time:5 |load:0 |reward:-0.0
# time:6 |load:0 |reward:-0.0
# time:7 |load:0 |reward:-0.0
# time:8 |load:0 |reward:-0.0
# |needed:30 |battery:20
# time:1 |load:0 |reward:-0.0
# time:2 |load:0 |reward:-0.0
# time:3 |load:0 |reward:-0.0
# time:4 |load:0 |reward:-0.0
# time:5 |load:0 |reward:-0.0
# time:6 |load:0 |reward:-0.0
# time:7 |load:0 |reward:-0.0
# time:8 |load:0 |reward:-0.0
# |needed:30 |battery:20
# time:1 |load:0 |reward:-0.0
# time:2 |load:0 |reward:-0.0
# time:3 |load:0 |reward:-0.0
# time:4 |load:0 |reward:-0.0
# time:5 |load:0 |reward:-0.0
# time:6 |load:0 |reward:-0.0
# time:7 |load:0 |reward:-0.0
# time:8 |load:0 |reward:-0.0
# |needed:30 |battery:20
# time:1 |load:0 |reward:-0.0
# time:2 |load:0 |reward:-0.0
# time:3 |load:0 |reward:-0.0
# time:4 |load:0 |reward:-0.0
# time:5 |load:0 |reward:-0.0
# time:6 |load:0 |reward:-0.0
# time:7 |load:0 |reward:-0.0
# time:8 |load:0 |reward:-0.0
# |needed:30 |battery:20
# time:1 |load:0 |reward:-0.0
# time:2 |load:0 |reward:-0.0
# time:3 |load:0 |reward:-0.0
# time:4 |load:0 |reward:-0.0
# time:5 |load:0 |reward:-0.0
# time:6 |load:0 |reward:-0.0
# time:7 |load:0 |reward:-0.0
# time:8 |load:0 |reward:-0.0
# |needed:30 |battery:20
#   288/10000 [..............................] - ETA: 10s - reward: -3.1250time:1 |load:0 |reward:-0.0
# time:2 |load:0 |reward:-0.0
# time:3 |load:0 |reward:-0.0
# time:4 |load:0 |reward:-0.0
# time:5 |load:0 |reward:-0.0
# time:6 |load:0 |reward:-0.0
# time:7 |load:0 |reward:-0.0
# time:8 |load:0 |reward:-0.0
# |needed:30 |battery:20
# time:1 |load:0 |reward:-0.0
# time:2 |load:0 |reward:-0.0
# time:3 |load:0 |reward:-0.0
# time:4 |load:0 |reward:-0.0
# time:5 |load:0 |reward:-0.0
# time:6 |load:0 |reward:-0.0
# time:7 |load:0 |reward:-0.0
# time:8 |load:0 |reward:-0.0
# |needed:30 |battery:20
# time:1 |load:0 |reward:-0.0
# time:2 |load:0 |reward:-0.0
# time:3 |load:0 |reward:-0.0
# time:4 |load:0 |reward:-0.0
# time:5 |load:0 |reward:-0.0
# time:6 |load:0 |reward:-0.0
# time:7 |load:0 |reward:-0.0
# time:8 |load:0 |reward:-0.0
# |needed:30 |battery:20
# time:1 |load:0 |reward:-0.0
# time:2 |load:0 |reward:-0.0
# time:3 |load:0 |reward:-0.0
# time:4 |load:0 |reward:-0.0
# time:5 |load:0 |reward:-0.0
# time:6 |load:0 |reward:-0.0
# time:7 |load:0 |reward:-0.0
# time:8 |load:0 |reward:-0.0
# |needed:30 |battery:20
# time:1 |load:0 |reward:-0.0
# time:2 |load:0 |reward:-0.0
# time:3 |load:0 |reward:-0.0
# time:4 |load:0 |reward:-0.0
# time:5 |load:0 |reward:-0.0
# time:6 |load:0 |reward:-0.0
# time:7 |load:0 |reward:-0.0
# time:8 |load:0 |reward:-0.0
# |needed:30 |battery:20
# time:1 |load:0 |reward:-0.0
# time:2 |load:0 |reward:-0.0
# time:3 |load:0 |reward:-0.0
# time:4 |load:0 |reward:-0.0
# time:5 |load:0 |reward:-0.0
# time:6 |load:0 |reward:-0.0
# time:7 |load:0 |reward:-0.0
# time:8 |load:0 |reward:-0.0
# |needed:30 |battery:20
# time:1 |load:0 |reward:-0.0
# time:2 |load:0 |reward:-0.0
# time:3 |load:0 |reward:-0.0
# time:4 |load:0 |reward:-0.0
# time:5 |load:0 |reward:-0.0
# time:6 |load:0 |reward:-0.0
# time:7 |load:0 |reward:-0.0
# time:8 |load:0 |reward:-0.0
# |needed:30 |battery:20
# time:1 |load:0 |reward:-0.0
#   345/10000 [>.............................] - ETA: 9s - reward: -3.1159 time:2 |load:0 |reward:-0.0
# time:3 |load:0 |reward:-0.0
# time:4 |load:0 |reward:-0.0
# time:5 |load:0 |reward:-0.0
# time:6 |load:0 |reward:-0.0
# time:7 |load:0 |reward:-0.0
# time:8 |load:0 |reward:-0.0
# |needed:30 |battery:20
# time:1 |load:0 |reward:-0.0
# time:2 |load:0 |reward:-0.0
# time:3 |load:0 |reward:-0.0
# time:4 |load:0 |reward:-0.0
# time:5 |load:0 |reward:-0.0
# time:6 |load:0 |reward:-0.0
# time:7 |load:0 |reward:-0.0
# time:8 |load:0 |reward:-0.0
# |needed:30 |battery:20
# time:1 |load:0 |reward:-0.0
# time:2 |load:0 |reward:-0.0
# time:3 |load:0 |reward:-0.0
# time:4 |load:0 |reward:-0.0
# time:5 |load:0 |reward:-0.0
# time:6 |load:0 |reward:-0.0
# time:7 |load:0 |reward:-0.0
# time:8 |load:0 |reward:-0.0
# |needed:30 |battery:20
# time:1 |load:0 |reward:-0.0
# time:2 |load:0 |reward:-0.0
# time:3 |load:0 |reward:-0.0
# time:4 |load:0 |reward:-0.0
# time:5 |load:0 |reward:-0.0
# time:6 |load:0 |reward:-0.0
# time:7 |load:0 |reward:-0.0
# time:8 |load:0 |reward:-0.0
# |needed:30 |battery:20
# time:1 |load:0 |reward:-0.0
# time:2 |load:0 |reward:-0.0
# time:3 |load:0 |reward:-0.0
# time:4 |load:0 |reward:-0.0
# time:5 |load:0 |reward:-0.0
# time:6 |load:0 |reward:-0.0
# time:7 |load:0 |reward:-0.0
# time:8 |load:0 |reward:-0.0
# |needed:30 |battery:20
# time:1 |load:0 |reward:-0.0
# time:2 |load:0 |reward:-0.0
# time:3 |load:0 |reward:-0.0
# time:4 |load:0 |reward:-0.0
# time:5 |load:0 |reward:-0.0
# time:6 |load:0 |reward:-0.0
# time:7 |load:0 |reward:-0.0
# time:8 |load:0 |reward:-0.0
# |needed:30 |battery:20
# time:1 |load:0 |reward:-0.0
# time:2 |load:0 |reward:-0.0
# time:3 |load:0 |reward:-0.0
# time:4 |load:0 |reward:-0.0
# time:5 |load:0 |reward:-0.0
# time:6 |load:0 |reward:-0.0
# time:7 |load:0 |reward:-0.0
# time:8 |load:0 |reward:-0.0
# |needed:30 |battery:20
# time:1 |load:0 |reward:-0.0
# time:2 |load:0 |reward:-0.0
# time:3 |load:0 |reward:-0.0
# time:4 |load:0 |reward:-0.0
# time:5 |load:0 |reward:-0.0
# time:6 |load:0 |reward:-0.0
# time:7 |load:0 |reward:-0.0
# time:8 |load:0 |reward:-0.0
# |needed:30 |battery:20
#   408/10000 [>.............................] - ETA: 9s - reward: -3.1250time:1 |load:0 |reward:-0.0
# time:2 |load:0 |reward:-0.0
# time:3 |load:0 |reward:-0.0
# time:4 |load:0 |reward:-0.0
# time:5 |load:0 |reward:-0.0
# time:6 |load:0 |reward:-0.0
# time:7 |load:0 |reward:-0.0
# time:8 |load:0 |reward:-0.0
# |needed:30 |battery:20
# time:1 |load:0 |reward:-0.0
# time:2 |load:0 |reward:-0.0
# time:3 |load:0 |reward:-0.0
# time:4 |load:0 |reward:-0.0
# time:5 |load:0 |reward:-0.0
# time:6 |load:0 |reward:-0.0
# time:7 |load:0 |reward:-0.0
# time:8 |load:0 |reward:-0.0
# |needed:30 |battery:20
# time:1 |load:0 |reward:-0.0
# time:2 |load:0 |reward:-0.0
# time:3 |load:0 |reward:-0.0
# time:4 |load:0 |reward:-0.0
# time:5 |load:0 |reward:-0.0
# time:6 |load:0 |reward:-0.0
# time:7 |load:0 |reward:-0.0
# time:8 |load:0 |reward:-0.0
# |needed:30 |battery:20
# time:1 |load:0 |reward:-0.0
# time:2 |load:0 |reward:-0.0
# time:3 |load:0 |reward:-0.0
# time:4 |load:0 |reward:-0.0
# time:5 |load:0 |reward:-0.0
# time:6 |load:0 |reward:-0.0
# time:7 |load:0 |reward:-0.0
# time:8 |load:0 |reward:-0.0
# |needed:30 |battery:20
# time:1 |load:0 |reward:-0.0
# time:2 |load:0 |reward:-0.0
# time:3 |load:0 |reward:-0.0
# time:4 |load:0 |reward:-0.0
# time:5 |load:0 |reward:-0.0
# time:6 |load:0 |reward:-0.0
# time:7 |load:0 |reward:-0.0
# time:8 |load:0 |reward:-0.0
# |needed:30 |battery:20
# time:1 |load:0 |reward:-0.0
# time:2 |load:0 |reward:-0.0
# time:3 |load:0 |reward:-0.0
# time:4 |load:0 |reward:-0.0
# time:5 |load:0 |reward:-0.0
# time:6 |load:0 |reward:-0.0
# time:7 |load:0 |reward:-0.0
# time:8 |load:0 |reward:-0.0
# |needed:30 |battery:20
# time:1 |load:0 |reward:-0.0
# time:2 |load:0 |reward:-0.0
# time:3 |load:0 |reward:-0.0
# time:4 |load:0 |reward:-0.0
# time:5 |load:0 |reward:-0.0
# time:6 |load:0 |reward:-0.0
# time:7 |load:0 |reward:-0.0
# time:8 |load:0 |reward:-0.0
# |needed:30 |battery:20
# time:1 |load:0 |reward:-0.0
# time:2 |load:0 |reward:-0.0
# time:3 |load:0 |reward:-0.0
# time:4 |load:0 |reward:-0.0
# time:5 |load:0 |reward:-0.0
#   469/10000 [>.............................] - ETA: 9s - reward: -3.0917time:6 |load:0 |reward:-0.0
# time:7 |load:0 |reward:-0.0
# time:8 |load:0 |reward:-0.0
# |needed:30 |battery:20
# time:1 |load:0 |reward:-0.0
# time:2 |load:0 |reward:-0.0
# time:3 |load:0 |reward:-0.0
# time:4 |load:0 |reward:-0.0
# time:5 |load:0 |reward:-0.0
# time:6 |load:0 |reward:-0.0
# time:7 |load:0 |reward:-0.0
# time:8 |load:0 |reward:-0.0
# |needed:30 |battery:20
# time:1 |load:0 |reward:-0.0
# time:2 |load:0 |reward:-0.0
# time:3 |load:0 |reward:-0.0
# time:4 |load:0 |reward:-0.0
# time:5 |load:0 |reward:-0.0
# time:6 |load:0 |reward:-0.0
# time:7 |load:0 |reward:-0.0
# time:8 |load:0 |reward:-0.0
# |needed:30 |battery:20
# time:1 |load:0 |reward:-0.0
# time:2 |load:0 |reward:-0.0
# time:3 |load:0 |reward:-0.0
# time:4 |load:0 |reward:-0.0
# time:5 |load:0 |reward:-0.0
# time:6 |load:0 |reward:-0.0
# time:7 |load:0 |reward:-0.0
# time:8 |load:0 |reward:-0.0
# |needed:30 |battery:20
# time:1 |load:0 |reward:-0.0
# time:2 |load:0 |reward:-0.0
# time:3 |load:0 |reward:-0.0
# time:4 |load:0 |reward:-0.0
# time:5 |load:0 |reward:-0.0
# time:6 |load:0 |reward:-0.0
# time:7 |load:0 |reward:-0.0
# time:8 |load:0 |reward:-0.0
# |needed:30 |battery:20
# time:1 |load:0 |reward:-0.0
# time:2 |load:0 |reward:-0.0
# time:3 |load:0 |reward:-0.0
# time:4 |load:0 |reward:-0.0
# time:5 |load:0 |reward:-0.0
# time:6 |load:0 |reward:-0.0
# time:7 |load:0 |reward:-0.0
# time:8 |load:0 |reward:-0.0
# |needed:30 |battery:20
# time:1 |load:0 |reward:-0.0
# time:2 |load:0 |reward:-0.0
# time:3 |load:0 |reward:-0.0
# time:4 |load:0 |reward:-0.0
# time:5 |load:0 |reward:-0.0
# time:6 |load:0 |reward:-0.0
# time:7 |load:0 |reward:-0.0
# time:8 |load:0 |reward:-0.0
# |needed:30 |battery:20
# time:1 |load:0 |reward:-0.0
# time:2 |load:0 |reward:-0.0
# time:3 |load:0 |reward:-0.0
# time:4 |load:0 |reward:-0.0
# time:5 |load:0 |reward:-0.0
# time:6 |load:0 |reward:-0.0
# time:7 |load:0 |reward:-0.0
# time:8 |load:0 |reward:-0.0
# |needed:30 |battery:20
#   528/10000 [>.............................] - ETA: 9s - reward: -3.1250time:1 |load:0 |reward:-0.0
# time:2 |load:0 |reward:-0.0
# time:3 |load:0 |reward:-0.0
# time:4 |load:0 |reward:-0.0
# time:5 |load:0 |reward:-0.0
# time:6 |load:0 |reward:-0.0
# time:7 |load:0 |reward:-0.0
# time:8 |load:0 |reward:-0.0
# |needed:30 |battery:20
# time:1 |load:0 |reward:-0.0
# time:2 |load:0 |reward:-0.0
# time:3 |load:0 |reward:-0.0
# time:4 |load:0 |reward:-0.0
# time:5 |load:0 |reward:-0.0
# time:6 |load:0 |reward:-0.0
# time:7 |load:0 |reward:-0.0
# time:8 |load:0 |reward:-0.0
# |needed:30 |battery:20
# time:1 |load:0 |reward:-0.0
# time:2 |load:0 |reward:-0.0
# time:3 |load:0 |reward:-0.0
# time:4 |load:0 |reward:-0.0
# time:5 |load:0 |reward:-0.0
# time:6 |load:0 |reward:-0.0
# time:7 |load:0 |reward:-0.0
# time:8 |load:0 |reward:-0.0
# |needed:30 |battery:20
# time:1 |load:0 |reward:-0.0
# time:2 |load:0 |reward:-0.0
# time:3 |load:0 |reward:-0.0
# time:4 |load:0 |reward:-0.0
# time:5 |load:0 |reward:-0.0
# time:6 |load:0 |reward:-0.0
# time:7 |load:0 |reward:-0.0
# time:8 |load:0 |reward:-0.0
# |needed:30 |battery:20
# time:1 |load:0 |reward:-0.0
# time:2 |load:0 |reward:-0.0
# time:3 |load:0 |reward:-0.0
# time:4 |load:0 |reward:-0.0
# time:5 |load:0 |reward:-0.0
# time:6 |load:0 |reward:-0.0
# time:7 |load:0 |reward:-0.0
# time:8 |load:0 |reward:-0.0
# |needed:30 |battery:20
# time:1 |load:0 |reward:-0.0
# time:2 |load:0 |reward:-0.0
# time:3 |load:0 |reward:-0.0
# time:4 |load:0 |reward:-0.0
# time:5 |load:0 |reward:-0.0
# time:6 |load:0 |reward:-0.0
# time:7 |load:0 |reward:-0.0
# time:8 |load:0 |reward:-0.0
# |needed:30 |battery:20
# time:1 |load:0 |reward:-0.0
# time:2 |load:0 |reward:-0.0
# time:3 |load:0 |reward:-0.0
# time:4 |load:0 |reward:-0.0
# time:5 |load:0 |reward:-0.0
# time:6 |load:0 |reward:-0.0
# time:7 |load:0 |reward:-0.0
# time:8 |load:0 |reward:-0.0
# |needed:30 |battery:20
# time:1 |load:0 |reward:-0.0
# time:2 |load:0 |reward:-0.0
# time:3 |load:0 |reward:-0.0
# time:4 |load:0 |reward:-0.0
# time:5 |load:0 |reward:-0.0
# time:6 |load:0 |reward:-0.0
# time:7 |load:0 |reward:-0.0
# time:8 |load:0 |reward:-0.0
# |needed:30 |battery:20
# time:1 |load:0 |reward:-0.0
#   593/10000 [>.............................] - ETA: 8s - reward: -3.1197time:2 |load:0 |reward:-0.0
# time:3 |load:0 |reward:-0.0
# time:4 |load:0 |reward:-0.0
# time:5 |load:0 |reward:-0.0
# time:6 |load:0 |reward:-0.0
# time:7 |load:0 |reward:-0.0
# time:8 |load:0 |reward:-0.0
# |needed:30 |battery:20
# time:1 |load:0 |reward:-0.0
# time:2 |load:0 |reward:-0.0
# time:3 |load:0 |reward:-0.0
# time:4 |load:0 |reward:-0.0
# time:5 |load:0 |reward:-0.0
# time:6 |load:0 |reward:-0.0
# time:7 |load:0 |reward:-0.0
# time:8 |load:0 |reward:-0.0
# |needed:30 |battery:20
# time:1 |load:0 |reward:-0.0
# time:2 |load:0 |reward:-0.0
# time:3 |load:0 |reward:-0.0
# time:4 |load:0 |reward:-0.0
# time:5 |load:0 |reward:-0.0
# time:6 |load:0 |reward:-0.0
# time:7 |load:0 |reward:-0.0
# time:8 |load:0 |reward:-0.0
# |needed:30 |battery:20
# time:1 |load:0 |reward:-0.0
# time:2 |load:0 |reward:-0.0
# time:3 |load:0 |reward:-0.0
# time:4 |load:0 |reward:-0.0
# time:5 |load:0 |reward:-0.0
# time:6 |load:0 |reward:-0.0
# time:7 |load:0 |reward:-0.0
# time:8 |load:0 |reward:-0.0
# |needed:30 |battery:20
# time:1 |load:0 |reward:-0.0
# time:2 |load:0 |reward:-0.0
# time:3 |load:0 |reward:-0.0
# time:4 |load:0 |reward:-0.0
# time:5 |load:0 |reward:-0.0
# time:6 |load:0 |reward:-0.0
# time:7 |load:0 |reward:-0.0
# time:8 |load:0 |reward:-0.0
# |needed:30 |battery:20
# time:1 |load:0 |reward:-0.0
# time:2 |load:0 |reward:-0.0
# time:3 |load:0 |reward:-0.0
# time:4 |load:0 |reward:-0.0
# time:5 |load:0 |reward:-0.0
# time:6 |load:0 |reward:-0.0
# time:7 |load:0 |reward:-0.0
# time:8 |load:0 |reward:-0.0
# |needed:30 |battery:20
# time:1 |load:0 |reward:-0.0
# time:2 |load:0 |reward:-0.0
# time:3 |load:0 |reward:-0.0
# time:4 |load:0 |reward:-0.0
# time:5 |load:0 |reward:-0.0
# time:6 |load:0 |reward:-0.0
# time:7 |load:0 |reward:-0.0
# time:8 |load:0 |reward:-0.0
# |needed:30 |battery:20
# time:1 |load:0 |reward:-0.0
#   649/10000 [>.............................] - ETA: 8s - reward: -3.1202time:2 |load:0 |reward:-0.0
# time:3 |load:0 |reward:-0.0
# time:4 |load:0 |reward:-0.0
# time:5 |load:0 |reward:-0.0
# time:6 |load:0 |reward:-0.0
# time:7 |load:0 |reward:-0.0
# time:8 |load:0 |reward:-0.0
# |needed:30 |battery:20
# time:1 |load:0 |reward:-0.0
# time:2 |load:0 |reward:-0.0
# time:3 |load:0 |reward:-0.0
# time:4 |load:0 |reward:-0.0
# time:5 |load:0 |reward:-0.0
# time:6 |load:0 |reward:-0.0
# time:7 |load:0 |reward:-0.0
# time:8 |load:0 |reward:-0.0
# |needed:30 |battery:20
# time:1 |load:0 |reward:-0.0
# time:2 |load:0 |reward:-0.0
# time:3 |load:0 |reward:-0.0
# time:4 |load:0 |reward:-0.0
# time:5 |load:0 |reward:-0.0
# time:6 |load:0 |reward:-0.0
# time:7 |load:0 |reward:-0.0
# time:8 |load:0 |reward:-0.0
# |needed:30 |battery:20
# time:1 |load:0 |reward:-0.0
# time:2 |load:0 |reward:-0.0
# time:3 |load:0 |reward:-0.0
# time:4 |load:0 |reward:-0.0
# time:5 |load:0 |reward:-0.0
# time:6 |load:0 |reward:-0.0
# time:7 |load:0 |reward:-0.0
# time:8 |load:0 |reward:-0.0
# |needed:30 |battery:20
# time:1 |load:0 |reward:-0.0
# time:2 |load:0 |reward:-0.0
# time:3 |load:0 |reward:-0.0
# time:4 |load:0 |reward:-0.0
# time:5 |load:0 |reward:-0.0
# time:6 |load:0 |reward:-0.0
# time:7 |load:0 |reward:-0.0
# time:8 |load:0 |reward:-0.0
# |needed:30 |battery:20
# time:1 |load:0 |reward:-0.0
# time:2 |load:0 |reward:-0.0
# time:3 |load:0 |reward:-0.0
# time:4 |load:0 |reward:-0.0
# time:5 |load:0 |reward:-0.0
# time:6 |load:0 |reward:-0.0
# time:7 |load:0 |reward:-0.0
# time:8 |load:0 |reward:-0.0
# |needed:30 |battery:20
# time:1 |load:0 |reward:-0.0
# time:2 |load:0 |reward:-0.0
# time:3 |load:0 |reward:-0.0
#   699/10000 [=>............................] - ETA: 8s - reward: -3.1116time:4 |load:0 |reward:-0.0
# time:5 |load:0 |reward:-0.0
# time:6 |load:0 |reward:-0.0
# time:7 |load:0 |reward:-0.0
# time:8 |load:0 |reward:-0.0
# |needed:30 |battery:20
# time:1 |load:0 |reward:-0.0
# time:2 |load:0 |reward:-0.0
# time:3 |load:0 |reward:-0.0
# time:4 |load:0 |reward:-0.0
# time:5 |load:0 |reward:-0.0
# time:6 |load:0 |reward:-0.0
# time:7 |load:0 |reward:-0.0
# time:8 |load:0 |reward:-0.0
# |needed:30 |battery:20
# time:1 |load:0 |reward:-0.0
# time:2 |load:0 |reward:-0.0
# time:3 |load:0 |reward:-0.0
# time:4 |load:0 |reward:-0.0
# time:5 |load:0 |reward:-0.0
# time:6 |load:0 |reward:-0.0
# time:7 |load:0 |reward:-0.0
# time:8 |load:0 |reward:-0.0
# |needed:30 |battery:20
# time:1 |load:0 |reward:-0.0
# time:2 |load:0 |reward:-0.0
# time:3 |load:0 |reward:-0.0
# time:4 |load:0 |reward:-0.0
# time:5 |load:0 |reward:-0.0
# time:6 |load:0 |reward:-0.0
# time:7 |load:0 |reward:-0.0
# time:8 |load:0 |reward:-0.0
# |needed:30 |battery:20
# time:1 |load:0 |reward:-0.0
# time:2 |load:0 |reward:-0.0
# time:3 |load:0 |reward:-0.0
# time:4 |load:0 |reward:-0.0
# time:5 |load:0 |reward:-0.0
# time:6 |load:0 |reward:-0.0
# time:7 |load:0 |reward:-0.0
# time:8 |load:0 |reward:-0.0
# |needed:30 |battery:20
# time:1 |load:0 |reward:-0.0
# time:2 |load:0 |reward:-0.0
# time:3 |load:0 |reward:-0.0
# time:4 |load:0 |reward:-0.0
# time:5 |load:0 |reward:-0.0
# time:6 |load:0 |reward:-0.0
# time:7 |load:0 |reward:-0.0
# time:8 |load:0 |reward:-0.0
# |needed:30 |battery:20
# time:1 |load:0 |reward:-0.0
# time:2 |load:0 |reward:-0.0
# time:3 |load:0 |reward:-0.0
# time:4 |load:0 |reward:-0.0
# time:5 |load:0 |reward:-0.0
# time:6 |load:0 |reward:-0.0
# time:7 |load:0 |reward:-0.0
# time:8 |load:0 |reward:-0.0
# |needed:30 |battery:20
# time:1 |load:0 |reward:-0.0
# time:2 |load:0 |reward:-0.0
# time:3 |load:0 |reward:-0.0
# time:4 |load:0 |reward:-0.0
# time:5 |load:0 |reward:-0.0
# time:6 |load:0 |reward:-0.0
# time:7 |load:0 |reward:-0.0
#   759/10000 [=>............................] - ETA: 8s - reward: -3.0962time:8 |load:0 |reward:-0.0
# |needed:30 |battery:20
# time:1 |load:0 |reward:-0.0
# time:2 |load:0 |reward:-0.0
# time:3 |load:0 |reward:-0.0
# time:4 |load:0 |reward:-0.0
# time:5 |load:0 |reward:-0.0
# time:6 |load:0 |reward:-0.0
# time:7 |load:0 |reward:-0.0
# time:8 |load:0 |reward:-0.0
# |needed:30 |battery:20
# time:1 |load:0 |reward:-0.0
# time:2 |load:0 |reward:-0.0
# time:3 |load:0 |reward:-0.0
# time:4 |load:0 |reward:-0.0
# time:5 |load:0 |reward:-0.0
# time:6 |load:0 |reward:-0.0
# time:7 |load:0 |reward:-0.0
# time:8 |load:0 |reward:-0.0
# |needed:30 |battery:20
# time:1 |load:0 |reward:-0.0
# time:2 |load:0 |reward:-0.0
# time:3 |load:0 |reward:-0.0
# time:4 |load:0 |reward:-0.0
# time:5 |load:0 |reward:-0.0
# time:6 |load:0 |reward:-0.0
# time:7 |load:0 |reward:-0.0
# time:8 |load:0 |reward:-0.0
# |needed:30 |battery:20
# time:1 |load:0 |reward:-0.0
# time:2 |load:0 |reward:-0.0
# time:3 |load:0 |reward:-0.0
# time:4 |load:0 |reward:-0.0
# time:5 |load:0 |reward:-0.0
# time:6 |load:0 |reward:-0.0
# time:7 |load:0 |reward:-0.0
# time:8 |load:0 |reward:-0.0
# |needed:30 |battery:20
# time:1 |load:0 |reward:-0.0
# time:2 |load:0 |reward:-0.0
# time:3 |load:0 |reward:-0.0
# time:4 |load:0 |reward:-0.0
# time:5 |load:0 |reward:-0.0
# time:6 |load:0 |reward:-0.0
# time:7 |load:0 |reward:-0.0
# time:8 |load:0 |reward:-0.0
# |needed:30 |battery:20
# time:1 |load:0 |reward:-0.0
# time:2 |load:0 |reward:-0.0
#   802/10000 [=>............................] - ETA: 17s - reward: -3.1172time:3 |load:0 |reward:-0.0
# time:4 |load:0 |reward:-0.0
# time:5 |load:0 |reward:-0.0
# time:6 |load:0 |reward:-0.0
# time:7 |load:0 |reward:-0.0
# time:8 |load:0 |reward:-0.0
# |needed:30 |battery:20
# time:1 |load:0 |reward:-0.0
#   809/10000 [=>............................] - ETA: 17s - reward: -3.1211time:2 |load:0 |reward:-0.0
# time:3 |load:0 |reward:-0.0
# time:4 |load:0 |reward:-0.0
# time:5 |load:0 |reward:-0.0
# time:6 |load:0 |reward:-0.0
# time:7 |load:0 |reward:-0.0
# time:8 |load:0 |reward:-0.0
# |needed:30 |battery:20
#   816/10000 [=>............................] - ETA: 18s - reward: -3.1250time:1 |load:0 |reward:-0.0
# time:2 |load:0 |reward:-0.0
# time:3 |load:0 |reward:-0.0
# time:4 |load:0 |reward:-0.0
# time:5 |load:0 |reward:-0.0
# time:6 |load:0 |reward:-0.0
#   822/10000 [=>............................] - ETA: 18s - reward: -3.1022time:7 |load:0 |reward:-0.0
# time:8 |load:0 |reward:-0.0
# |needed:30 |battery:20
# time:1 |load:0 |reward:-0.0
# time:2 |load:0 |reward:-0.0
# time:3 |load:0 |reward:-0.0
# time:4 |load:0 |reward:-0.0
#   828/10000 [=>............................] - ETA: 18s - reward: -3.1099time:5 |load:0 |reward:-0.0
# time:6 |load:0 |reward:-0.0
# time:7 |load:0 |reward:-0.0
# time:8 |load:0 |reward:-0.0
# |needed:30 |battery:20
# time:1 |load:0 |reward:-0.0
# time:2 |load:0 |reward:-0.0
# time:3 |load:0 |reward:-0.0
#   835/10000 [=>............................] - ETA: 19s - reward: -3.1138time:4 |load:0 |reward:-0.0
# time:5 |load:0 |reward:-0.0
# time:6 |load:0 |reward:-0.0
# time:7 |load:0 |reward:-0.0
# time:8 |load:0 |reward:-0.0
# |needed:30 |battery:20
# time:1 |load:0 |reward:-0.0
#   841/10000 [=>............................] - ETA: 19s - reward: -3.1213time:2 |load:0 |reward:-0.0
# time:3 |load:0 |reward:-0.0
# time:4 |load:0 |reward:-0.0
# time:5 |load:0 |reward:-0.0
# time:6 |load:0 |reward:-0.0
# time:7 |load:0 |reward:-0.0
# time:8 |load:0 |reward:-0.0
# |needed:30 |battery:20
#   848/10000 [=>............................] - ETA: 20s - reward: -3.1250time:1 |load:0 |reward:-0.0
# time:2 |load:0 |reward:-0.0
# time:3 |load:0 |reward:-0.0
# time:4 |load:0 |reward:-0.0
# time:5 |load:0 |reward:-0.0
# time:6 |load:0 |reward:-0.0
#   854/10000 [=>............................] - ETA: 20s - reward: -3.1030time:7 |load:0 |reward:-0.0
# time:8 |load:0 |reward:-0.0
# |needed:30 |battery:20
# time:1 |load:0 |reward:-0.0
# time:2 |load:0 |reward:-0.0
# time:3 |load:0 |reward:-0.0
# time:4 |load:0 |reward:-0.0
# time:5 |load:0 |reward:-0.0
#   861/10000 [=>............................] - ETA: 21s - reward: -3.1069time:6 |load:0 |reward:-0.0
# time:7 |load:0 |reward:-0.0
# time:8 |load:0 |reward:-0.0
# |needed:30 |battery:20
# time:1 |load:0 |reward:-0.0
# time:2 |load:0 |reward:-0.0
# time:3 |load:0 |reward:-0.0
#   867/10000 [=>............................] - ETA: 21s - reward: -3.1142time:4 |load:0 |reward:-0.0
# time:5 |load:0 |reward:-0.0
# time:6 |load:0 |reward:-0.0
# time:7 |load:0 |reward:-0.0
# time:8 |load:0 |reward:-0.0
# |needed:30 |battery:20
# time:1 |load:0 |reward:-0.0
#   873/10000 [=>............................] - ETA: 21s - reward: -3.1214time:2 |load:0 |reward:-0.0
# time:3 |load:0 |reward:-0.0
# time:4 |load:0 |reward:-0.0
# time:5 |load:0 |reward:-0.0
# time:6 |load:0 |reward:-0.0
# time:7 |load:0 |reward:-0.0
# time:8 |load:0 |reward:-0.0
# |needed:30 |battery:20
# time:1 |load:0 |reward:-0.0
#   881/10000 [=>............................] - ETA: 22s - reward: -3.1215time:2 |load:0 |reward:-0.0
# time:3 |load:0 |reward:-0.0
# time:4 |load:0 |reward:-0.0
# time:5 |load:0 |reward:-0.0
# time:6 |load:0 |reward:-0.0
# time:7 |load:0 |reward:-0.0
# time:8 |load:0 |reward:-0.0
# |needed:30 |battery:20
# time:1 |load:0 |reward:-0.0
#   889/10000 [=>............................] - ETA: 22s - reward: -3.1215time:2 |load:0 |reward:-0.0
# time:3 |load:0 |reward:-0.0
# time:4 |load:0 |reward:-0.0
# time:5 |load:0 |reward:-0.0
# time:6 |load:0 |reward:-0.0
# time:7 |load:0 |reward:-0.0
# time:8 |load:0 |reward:-0.0
# |needed:30 |battery:20
# time:1 |load:0 |reward:-0.0
#   897/10000 [=>............................] - ETA: 23s - reward: -3.1215time:2 |load:0 |reward:-0.0
# time:3 |load:0 |reward:-0.0
# time:4 |load:0 |reward:-0.0
# time:5 |load:0 |reward:-0.0
# time:6 |load:0 |reward:-0.0
# time:7 |load:0 |reward:-0.0
# time:8 |load:1.75 |reward:-0.22
# |needed:30 |battery:21.75
#   904/10000 [=>............................] - ETA: 23s - reward: -3.1252time:1 |load:0 |reward:-0.0
# time:2 |load:0 |reward:-0.0
# time:3 |load:0 |reward:-0.0
# time:4 |load:0 |reward:-0.0
# time:5 |load:0 |reward:-0.0
# time:6 |load:0 |reward:-0.0
# time:7 |load:0 |reward:-0.0
#   911/10000 [=>............................] - ETA: 23s - reward: -3.1012time:8 |load:1.75 |reward:-0.22
# |needed:30 |battery:21.75
# time:1 |load:0 |reward:-0.0
# time:2 |load:0 |reward:-0.0
# time:3 |load:0 |reward:-0.0
# time:4 |load:0 |reward:-0.0
# time:5 |load:0 |reward:-0.0
# time:6 |load:0 |reward:-0.0
#   918/10000 [=>............................] - ETA: 24s - reward: -3.1051time:7 |load:0 |reward:-0.0
# time:8 |load:0 |reward:-0.0
# |needed:30 |battery:20
# time:1 |load:0 |reward:-0.0
# time:2 |load:0 |reward:-0.0
# time:3 |load:0 |reward:-0.0
#   923/10000 [=>............................] - ETA: 24s - reward: -3.1153time:4 |load:0 |reward:-0.0
# time:5 |load:0 |reward:-0.0
# time:6 |load:0 |reward:-0.0
# time:7 |load:0 |reward:-0.0
# time:8 |load:0 |reward:-0.0
# |needed:30 |battery:20
# time:1 |load:0 |reward:-0.0
#   929/10000 [=>............................] - ETA: 24s - reward: -3.1221time:2 |load:0 |reward:-0.0
# time:3 |load:0 |reward:-0.0
# time:4 |load:0 |reward:-0.0
# time:5 |load:0 |reward:-0.0
# time:6 |load:0 |reward:-0.0
# time:7 |load:0 |reward:-0.0
# time:8 |load:0 |reward:-0.0
# |needed:30 |battery:20
#   936/10000 [=>............................] - ETA: 25s - reward: -3.1255time:1 |load:0 |reward:-0.0
# time:2 |load:0 |reward:-0.0
# time:3 |load:0 |reward:-0.0
# time:4 |load:0 |reward:-0.0
# time:5 |load:0 |reward:-0.0
# time:6 |load:0 |reward:-0.0
#   942/10000 [=>............................] - ETA: 25s - reward: -3.1056time:7 |load:0 |reward:-0.0
# time:8 |load:0 |reward:-0.0
# |needed:30 |battery:20
# time:1 |load:0 |reward:-0.0
# time:2 |load:0 |reward:-0.0
# time:3 |load:0 |reward:-0.0
# time:4 |load:0 |reward:-0.0
# time:5 |load:0 |reward:-0.0
#   949/10000 [=>............................] - ETA: 25s - reward: -3.1090time:6 |load:0 |reward:-0.0
# time:7 |load:0 |reward:-0.0
# time:8 |load:0 |reward:-0.0
# |needed:30 |battery:20
# time:1 |load:0 |reward:-0.0
# time:2 |load:0 |reward:-0.0
# time:3 |load:0 |reward:-0.0
# time:4 |load:0 |reward:-0.0
#   956/10000 [=>............................] - ETA: 26s - reward: -3.1124time:5 |load:0 |reward:-0.0
# time:6 |load:0 |reward:-0.0
# time:7 |load:0 |reward:-0.0
# time:8 |load:0 |reward:-0.0
# |needed:30 |battery:20
# time:1 |load:0 |reward:-0.0
# time:2 |load:0 |reward:-0.0
#   962/10000 [=>............................] - ETA: 26s - reward: -3.1190time:3 |load:0 |reward:-0.0
# time:4 |load:0 |reward:-0.0
# time:5 |load:0 |reward:-0.0
# time:6 |load:0 |reward:-0.0
# time:7 |load:0 |reward:-0.0
# time:8 |load:0 |reward:-0.0
# |needed:30 |battery:20
# time:1 |load:0 |reward:-0.0
#   969/10000 [=>............................] - ETA: 26s - reward: -3.1222time:2 |load:0 |reward:-0.0
# time:3 |load:0 |reward:-0.0
# time:4 |load:0 |reward:-0.0
# time:5 |load:0 |reward:-0.0
# time:6 |load:0 |reward:-0.0
# time:7 |load:0 |reward:-0.0
# time:8 |load:3.5 |reward:-0.44
# |needed:30 |battery:23.5
# time:1 |load:0 |reward:-0.0
#   977/10000 [=>............................] - ETA: 26s - reward: -3.1227time:2 |load:0 |reward:-0.0
# time:3 |load:0 |reward:-0.0
# time:4 |load:0 |reward:-0.0
# time:5 |load:0 |reward:-0.0
# time:6 |load:0 |reward:-0.0
# time:7 |load:0 |reward:-0.0
# time:8 |load:0 |reward:-0.0
# |needed:30 |battery:20
#   984/10000 [=>............................] - ETA: 27s - reward: -3.1259time:1 |load:0 |reward:-0.0
# time:2 |load:0 |reward:-0.0
# time:3 |load:0 |reward:-0.0
# time:4 |load:0 |reward:-0.0
# time:5 |load:0 |reward:-0.0
# time:6 |load:0 |reward:-0.0
#   990/10000 [=>............................] - ETA: 27s - reward: -3.1069time:7 |load:0 |reward:-0.0
# time:8 |load:0 |reward:-0.0
# |needed:30 |battery:20
# time:1 |load:0 |reward:-0.0
# time:2 |load:0 |reward:-0.0
# time:3 |load:0 |reward:-0.0
# time:4 |load:0 |reward:-0.0
# time:5 |load:0 |reward:-0.0
#   997/10000 [=>............................] - ETA: 27s - reward: -3.1102time:6 |load:0 |reward:-0.0
# time:7 |load:0 |reward:-0.0
# time:8 |load:0 |reward:-0.0
# |needed:30 |battery:20
# time:1 |load:0 |reward:-0.0
# time:2 |load:0 |reward:-0.0
# time:3 |load:0 |reward:-0.0
# time:4 |load:0 |reward:-0.0
#  1004/10000 [==>...........................] - ETA: 28s - reward: -3.1134time:5 |load:0 |reward:-0.0
# time:6 |load:0 |reward:-0.0
# time:7 |load:0 |reward:-0.0
# time:8 |load:0 |reward:-0.0
# |needed:30 |battery:20
# time:1 |load:0 |reward:-0.0
# time:2 |load:0 |reward:-0.0
# time:3 |load:0 |reward:-0.0
#  1011/10000 [==>...........................] - ETA: 28s - reward: -3.1166time:4 |load:0 |reward:-0.0
# time:5 |load:0 |reward:-0.0
# time:6 |load:0 |reward:-0.0
# time:7 |load:0 |reward:-0.0
# time:8 |load:0 |reward:-0.0
# |needed:30 |battery:20
# time:1 |load:0 |reward:-0.0
# time:2 |load:0 |reward:-0.0
#  1018/10000 [==>...........................] - ETA: 28s - reward: -3.1197time:3 |load:0 |reward:-0.0
# time:4 |load:0 |reward:-0.0
# time:5 |load:0 |reward:-0.0
# time:6 |load:0 |reward:-0.0
# time:7 |load:0 |reward:-0.0
# time:8 |load:0 |reward:-0.0
# |needed:30 |battery:20
# time:1 |load:0 |reward:-0.0
#  1025/10000 [==>...........................] - ETA: 28s - reward: -3.1228time:2 |load:0 |reward:-0.0
# time:3 |load:0 |reward:-0.0
# time:4 |load:0 |reward:-0.0
# time:5 |load:0 |reward:-0.0
# time:6 |load:0 |reward:-0.0
# time:7 |load:0 |reward:-0.0
# time:8 |load:0 |reward:-0.0
# |needed:30 |battery:20
# time:1 |load:0 |reward:-0.0
#  1033/10000 [==>...........................] - ETA: 29s - reward: -3.1228time:2 |load:0 |reward:-0.0
# time:3 |load:0 |reward:-0.0
# time:4 |load:0 |reward:-0.0
# time:5 |load:0 |reward:-0.0
# time:6 |load:0 |reward:-0.0
# time:7 |load:0 |reward:-0.0
# time:8 |load:0 |reward:-0.0
# |needed:30 |battery:20
# time:1 |load:0 |reward:-0.0
#  1041/10000 [==>...........................] - ETA: 29s - reward: -3.1228time:2 |load:0 |reward:-0.0
# time:3 |load:0 |reward:-0.0
# time:4 |load:0 |reward:-0.0
# time:5 |load:0 |reward:-0.0
# time:6 |load:0 |reward:-0.0
# time:7 |load:0 |reward:-0.0
# time:8 |load:0 |reward:-0.0
# |needed:30 |battery:20
# time:1 |load:0 |reward:-0.0
#  1049/10000 [==>...........................] - ETA: 29s - reward: -3.1229time:2 |load:0 |reward:-0.0
# time:3 |load:0 |reward:-0.0
# time:4 |load:0 |reward:-0.0
# time:5 |load:0 |reward:-0.0
# time:6 |load:0 |reward:-0.0
# time:7 |load:0 |reward:-0.0
# time:8 |load:0 |reward:-0.0
# |needed:30 |battery:20
#  1056/10000 [==>...........................] - ETA: 30s - reward: -3.1258time:1 |load:0 |reward:-0.0
# time:2 |load:0 |reward:-0.0
# time:3 |load:0 |reward:-0.0
# time:4 |load:0 |reward:-0.0
# time:5 |load:0 |reward:-0.0
#  1061/10000 [==>...........................] - ETA: 30s - reward: -3.1111time:6 |load:0 |reward:-0.0
# time:7 |load:0 |reward:-0.0
# time:8 |load:0 |reward:-0.0
# |needed:30 |battery:20
# time:1 |load:0 |reward:-0.0
# time:2 |load:0 |reward:-0.0
# time:3 |load:0 |reward:-0.0
#  1067/10000 [==>...........................] - ETA: 30s - reward: -3.1170time:4 |load:0 |reward:-0.0
# time:5 |load:0 |reward:-0.0
# time:6 |load:0 |reward:-0.0
# time:7 |load:0 |reward:-0.0
# time:8 |load:0 |reward:-0.0
# |needed:30 |battery:20
# time:1 |load:0 |reward:-0.0
#  1073/10000 [==>...........................] - ETA: 30s - reward: -3.1229time:2 |load:0 |reward:-0.0
# time:3 |load:0 |reward:-0.0
# time:4 |load:0 |reward:-0.0
# time:5 |load:0 |reward:-0.0
# time:6 |load:0 |reward:-0.0
# time:7 |load:0 |reward:-0.0
# time:8 |load:0 |reward:-0.0
# |needed:30 |battery:20
# time:1 |load:0 |reward:-0.0
#  1081/10000 [==>...........................] - ETA: 31s - reward: -3.1229time:2 |load:0 |reward:-0.0
# time:3 |load:0 |reward:-0.0
# time:4 |load:0 |reward:-0.0
# time:5 |load:0 |reward:-0.0
# time:6 |load:0 |reward:-0.0
# time:7 |load:0 |reward:-0.0
# time:8 |load:0 |reward:-0.0
# |needed:30 |battery:20
# time:1 |load:0 |reward:-0.0
#  1089/10000 [==>...........................] - ETA: 31s - reward: -3.1229time:2 |load:0 |reward:-0.0
# time:3 |load:0 |reward:-0.0
# time:4 |load:0 |reward:-0.0
# time:5 |load:0 |reward:-0.0
# time:6 |load:0 |reward:-0.0
# time:7 |load:0 |reward:-0.0
# time:8 |load:0 |reward:-0.0
# |needed:30 |battery:20
# time:1 |load:0 |reward:-0.0
#  1097/10000 [==>...........................] - ETA: 31s - reward: -3.1229time:2 |load:0 |reward:-0.0
# time:3 |load:0 |reward:-0.0
# time:4 |load:0 |reward:-0.0
# time:5 |load:0 |reward:-0.0
# time:6 |load:0 |reward:-0.0
# time:7 |load:0 |reward:-0.0
# time:8 |load:0 |reward:-0.0
# |needed:30 |battery:20
# time:1 |load:0 |reward:-0.0
#  1105/10000 [==>...........................] - ETA: 31s - reward: -3.1230time:2 |load:0 |reward:-0.0
# time:3 |load:0 |reward:-0.0
# time:4 |load:0 |reward:-0.0
# time:5 |load:0 |reward:-0.0
# time:6 |load:0 |reward:-0.0
# time:7 |load:0 |reward:-0.0
# time:8 |load:0 |reward:-0.0
# |needed:30 |battery:20
# time:1 |load:0 |reward:-0.0
#  1113/10000 [==>...........................] - ETA: 31s - reward: -3.1230time:2 |load:0 |reward:-0.0
# time:3 |load:0 |reward:-0.0
# time:4 |load:0 |reward:-0.0
# time:5 |load:0 |reward:-0.0
# time:6 |load:0 |reward:-0.0
# time:7 |load:0 |reward:-0.0
# time:8 |load:0 |reward:-0.0
# |needed:30 |battery:20
# time:1 |load:0 |reward:-0.0
#  1121/10000 [==>...........................] - ETA: 32s - reward: -3.1230time:2 |load:0 |reward:-0.0
# time:3 |load:0 |reward:-0.0
# time:4 |load:0 |reward:-0.0
# time:5 |load:0 |reward:-0.0
# time:6 |load:0 |reward:-0.0
# time:7 |load:0 |reward:-0.0
# time:8 |load:0 |reward:-0.0
# |needed:30 |battery:20
# time:1 |load:0 |reward:-0.0
#  1129/10000 [==>...........................] - ETA: 32s - reward: -3.1230time:2 |load:0 |reward:-0.0
# time:3 |load:0 |reward:-0.0
# time:4 |load:0 |reward:-0.0
# time:5 |load:0 |reward:-0.0
# time:6 |load:0 |reward:-0.0
# time:7 |load:0 |reward:-0.0
# time:8 |load:3.5 |reward:-0.44
# |needed:30 |battery:23.5
# time:1 |load:0 |reward:-0.0
#  1137/10000 [==>...........................] - ETA: 32s - reward: -3.1234time:2 |load:0 |reward:-0.0
# time:3 |load:0 |reward:-0.0
# time:4 |load:0 |reward:-0.0
# time:5 |load:0 |reward:-0.0
# time:6 |load:0 |reward:-0.0
# time:7 |load:0 |reward:-0.0
# time:8 |load:0 |reward:-0.0
# |needed:30 |battery:20
# time:1 |load:0 |reward:-0.0
#  1145/10000 [==>...........................] - ETA: 32s - reward: -3.1234time:2 |load:0 |reward:-0.0
# time:3 |load:0 |reward:-0.0
# time:4 |load:0 |reward:-0.0
# time:5 |load:0 |reward:-0.0
# time:6 |load:0 |reward:-0.0
# time:7 |load:0 |reward:-0.0
# time:8 |load:0 |reward:-0.0
# |needed:30 |battery:20
# time:1 |load:0 |reward:-0.0
#  1153/10000 [==>...........................] - ETA: 32s - reward: -3.1234time:2 |load:0 |reward:-0.0
# time:3 |load:0 |reward:-0.0
# time:4 |load:0 |reward:-0.0
# time:5 |load:0 |reward:-0.0
# time:6 |load:0 |reward:-0.0
# time:7 |load:0 |reward:-0.0
# time:8 |load:0 |reward:-0.0
# |needed:30 |battery:20
# time:1 |load:0 |reward:-0.0
#  1161/10000 [==>...........................] - ETA: 33s - reward: -3.1234time:2 |load:0 |reward:-0.0
# time:3 |load:0 |reward:-0.0
# time:4 |load:0 |reward:-0.0
# time:5 |load:0 |reward:-0.0
# time:6 |load:0 |reward:-0.0
# time:7 |load:0 |reward:-0.0
# time:8 |load:0 |reward:-0.0
# |needed:30 |battery:20
#  1168/10000 [==>...........................] - ETA: 33s - reward: -3.1261time:1 |load:0 |reward:-0.0
# time:2 |load:0 |reward:-0.0
# time:3 |load:0 |reward:-0.0
# time:4 |load:0 |reward:-0.0
# time:5 |load:0 |reward:-0.0
# time:6 |load:0 |reward:-0.0
# time:7 |load:0 |reward:-0.0
#  1175/10000 [==>...........................] - ETA: 33s - reward: -3.1075time:8 |load:0 |reward:-0.0
# |needed:30 |battery:20
# time:1 |load:0 |reward:-0.0
# time:2 |load:0 |reward:-0.0
# time:3 |load:0 |reward:-0.0
# time:4 |load:0 |reward:-0.0
# time:5 |load:0 |reward:-0.0
# time:6 |load:0 |reward:-0.0
#  1182/10000 [==>...........................] - ETA: 33s - reward: -3.1102time:7 |load:0 |reward:-0.0
# time:8 |load:0 |reward:-0.0
# |needed:30 |battery:20
# time:1 |load:0 |reward:-0.0
# time:2 |load:0 |reward:-0.0
# time:3 |load:0 |reward:-0.0
# time:4 |load:0 |reward:-0.0
#  1188/10000 [==>...........................] - ETA: 33s - reward: -3.1156time:5 |load:0 |reward:-0.0
# time:6 |load:0 |reward:-0.0
# time:7 |load:0 |reward:-0.0
# time:8 |load:0 |reward:-0.0
# |needed:30 |battery:20
# time:1 |load:0 |reward:-0.0
# time:2 |load:0 |reward:-0.0
#  1194/10000 [==>...........................] - ETA: 33s - reward: -3.1209time:3 |load:0 |reward:-0.0
# time:4 |load:0 |reward:-0.0
# time:5 |load:0 |reward:-0.0
# time:6 |load:0 |reward:-0.0
# time:7 |load:0 |reward:-0.0
# time:8 |load:0 |reward:-0.0
# |needed:30 |battery:20
# time:1 |load:0 |reward:-0.0
#  1201/10000 [==>...........................] - ETA: 34s - reward: -3.1235time:2 |load:0 |reward:-0.0
# time:3 |load:0 |reward:-0.0
# time:4 |load:0 |reward:-0.0
# time:5 |load:0 |reward:-0.0
# time:6 |load:0 |reward:-0.0
# time:7 |load:0 |reward:-0.0
# time:8 |load:0 |reward:-0.0
# |needed:30 |battery:20
# time:1 |load:0 |reward:-0.0
#  1209/10000 [==>...........................] - ETA: 34s - reward: -3.1235time:2 |load:0 |reward:-0.0
# time:3 |load:0 |reward:-0.0
# time:4 |load:0 |reward:-0.0
# time:5 |load:0 |reward:-0.0
# time:6 |load:0 |reward:-0.0
# time:7 |load:0 |reward:-0.0
# time:8 |load:0 |reward:-0.0
# |needed:30 |battery:20
# time:1 |load:0 |reward:-0.0
#  1217/10000 [==>...........................] - ETA: 34s - reward: -3.1235time:2 |load:0 |reward:-0.0
# time:3 |load:0 |reward:-0.0
# time:4 |load:0 |reward:-0.0
# time:5 |load:0 |reward:-0.0
# time:6 |load:0 |reward:-0.0
# time:7 |load:0 |reward:-0.0
# time:8 |load:0 |reward:-0.0
# |needed:30 |battery:20
# time:1 |load:0 |reward:-0.0
#  1225/10000 [==>...........................] - ETA: 34s - reward: -3.1235time:2 |load:0 |reward:-0.0
# time:3 |load:0 |reward:-0.0
# time:4 |load:0 |reward:-0.0
# time:5 |load:0 |reward:-0.0
# time:6 |load:0 |reward:-0.0
# time:7 |load:0 |reward:-0.0
#  1231/10000 [==>...........................] - ETA: 34s - reward: -3.1083time:8 |load:3.5 |reward:-0.44
# |needed:30 |battery:23.5
# time:1 |load:0 |reward:-0.0
# time:2 |load:0 |reward:-0.0
# time:3 |load:0 |reward:-0.0
# time:4 |load:0 |reward:-0.0
# time:5 |load:0 |reward:-0.0
# time:6 |load:0 |reward:-0.0
#  1238/10000 [==>...........................] - ETA: 34s - reward: -3.1113time:7 |load:0 |reward:-0.0
# time:8 |load:0 |reward:-0.0
# |needed:30 |battery:20
# time:1 |load:0 |reward:-0.0
# time:2 |load:0 |reward:-0.0
# time:3 |load:0 |reward:-0.0
# time:4 |load:0 |reward:-0.0
# time:5 |load:0 |reward:-0.0
#  1245/10000 [==>...........................] - ETA: 35s - reward: -3.1139time:6 |load:0 |reward:-0.0
# time:7 |load:3.5 |reward:-0.5
# time:8 |load:0 |reward:-0.0
# |needed:30 |battery:23.5
# time:1 |load:0 |reward:-0.0
# time:2 |load:0 |reward:-0.0
# time:3 |load:0 |reward:-0.0
# time:4 |load:0 |reward:-0.0
#  1252/10000 [==>...........................] - ETA: 35s - reward: -3.1168time:5 |load:0 |reward:-0.0
# time:6 |load:0 |reward:-0.0
# time:7 |load:3.5 |reward:-0.5
# time:8 |load:0 |reward:-0.0
# |needed:30 |battery:23.5
# time:1 |load:0 |reward:-0.0
# time:2 |load:0 |reward:-0.0
# time:3 |load:0 |reward:-0.0
#  1259/10000 [==>...........................] - ETA: 35s - reward: -3.1197time:4 |load:0 |reward:-0.0
# time:5 |load:0 |reward:-0.0
# time:6 |load:3.5 |reward:-0.58
# time:7 |load:0 |reward:-0.0
# time:8 |load:3.5 |reward:-0.44
# |needed:30 |battery:27.0
# time:1 |load:0 |reward:-0.0
# time:2 |load:0 |reward:-0.0
#  1266/10000 [==>...........................] - ETA: 35s - reward: -3.1230time:3 |load:0 |reward:-0.0
# time:4 |load:0 |reward:-0.0
# time:5 |load:0 |reward:-0.0
# time:6 |load:0 |reward:-0.0
# time:7 |load:3.5 |reward:-0.5
# time:8 |load:3.5 |reward:-0.44
# |needed:30 |battery:27.0
# time:1 |load:0 |reward:-0.0
#  1273/10000 [==>...........................] - ETA: 35s - reward: -3.1262time:2 |load:0 |reward:-0.0
# time:3 |load:0 |reward:-0.0
# time:4 |load:0 |reward:-0.0
# time:5 |load:0 |reward:-0.0
# time:6 |load:0 |reward:-0.0
# time:7 |load:0 |reward:-0.0
# time:8 |load:3.5 |reward:-0.44
# |needed:30 |battery:23.5
#  1280/10000 [==>...........................] - ETA: 35s - reward: -3.1290time:1 |load:0 |reward:-0.0
# time:2 |load:0 |reward:-0.0
# time:3 |load:0 |reward:-0.0
# time:4 |load:0 |reward:-0.0
# time:5 |load:0 |reward:-0.0
# time:6 |load:0 |reward:-0.0
# time:7 |load:3.5 |reward:-0.5
#  1287/10000 [==>...........................] - ETA: 35s - reward: -3.1124time:8 |load:3.5 |reward:-0.44
# |needed:30 |battery:27.0
# time:1 |load:0 |reward:-0.0
# time:2 |load:0 |reward:-0.0
# time:3 |load:0 |reward:-0.0
# time:4 |load:0 |reward:-0.0
# time:5 |load:0 |reward:-0.0
# time:6 |load:0 |reward:-0.0
#  1294/10000 [==>...........................] - ETA: 36s - reward: -3.1152time:7 |load:3.5 |reward:-0.5
# time:8 |load:0 |reward:-0.0
# |needed:30 |battery:23.5
# time:1 |load:0 |reward:-0.0
# time:2 |load:0 |reward:-0.0
# time:3 |load:0 |reward:-0.0
# time:4 |load:0 |reward:-0.0
#  1300/10000 [==>...........................] - ETA: 36s - reward: -3.1204time:5 |load:0 |reward:-0.0
# time:6 |load:0 |reward:-0.0
# time:7 |load:0 |reward:-0.0
# time:8 |load:0 |reward:-0.0
# |needed:30 |battery:20
# time:1 |load:0 |reward:-0.0
# time:2 |load:0 |reward:-0.0
# time:3 |load:0 |reward:-0.0
#  1307/10000 [==>...........................] - ETA: 36s - reward: -3.1229time:4 |load:0 |reward:-0.0
# time:5 |load:0 |reward:-0.0
# time:6 |load:0 |reward:-0.0
# time:7 |load:0 |reward:-0.0
# time:8 |load:0 |reward:-0.0
# |needed:30 |battery:20
# time:1 |load:0 |reward:-0.0
#  1313/10000 [==>...........................] - ETA: 36s - reward: -3.1276time:2 |load:0 |reward:-0.0
# time:3 |load:0 |reward:-0.0
# time:4 |load:0 |reward:-0.0
# time:5 |load:0 |reward:-0.0
# time:6 |load:0 |reward:-0.0
# time:7 |load:0 |reward:-0.0
# time:8 |load:0 |reward:-0.0
# |needed:30 |battery:20
#  1320/10000 [==>...........................] - ETA: 36s - reward: -3.1300time:1 |load:0 |reward:-0.0
# time:2 |load:0 |reward:-0.0
# time:3 |load:0 |reward:-0.0
# time:4 |load:0 |reward:-0.0
# time:5 |load:0 |reward:-0.0
# time:6 |load:0 |reward:-0.0
# ...
# time:4 |load:0 |reward:-0.0
#  2548/10000 [======>.......................] - ETA: 45s - reward: -3.1482time:5 |load:1.75 |reward:-0.35
# time:6 |load:1.75 |reward:-0.29
# time:7 |load:0 |reward:-0.0
# time:8 |load:0 |reward:-0.0
# |needed:30 |battery:23.5
# time:1 |load:1.75 |reward:-1.75
# time:2 |load:0 |reward:-0.0
#  2554/10000 [======>.......................] - ETA: 45s - reward: -3.1516time:3 |load:0 |reward:-0.0
# time:4 |load:0 |reward:-0.0
# time:5 |load:0 |reward:-0.0
# time:6 |load:0 |reward:-0.0
# time:7 |load:0 |reward:-0.0
# time:8 |load:0 |reward:-0.0
# |needed:30 |battery:21.75
# time:1 |load:0 |reward:-0.0
# time:2 |load:0 |reward:-0.0
#  2562/10000 [======>.......................] - ETA: 45s - reward: -3.1515time:3 |load:0 |reward:-0.0
# time:4 |load:0 |reward:-0.0
# time:5 |load:0 |reward:-0.0
# time:6 |load:0 |reward:-0.0
# time:7 |load:0 |reward:-0.0
# time:8 |load:0 |reward:-0.0
# |needed:30 |battery:20
# time:1 |load:0 |reward:-0.0
#  2569/10000 [======>.......................] - ETA: 45s - reward: -3.1526time:2 |load:0 |reward:-0.0
# time:3 |load:0 |reward:-0.0
# time:4 |load:0 |reward:-0.0
# time:5 |load:0 |reward:-0.0
# time:6 |load:1.75 |reward:-0.29
# time:7 |load:0 |reward:-0.0
# time:8 |load:0 |reward:-0.0
# |needed:30 |battery:21.75
#  2576/10000 [======>.......................] - ETA: 45s - reward: -3.1539time:1 |load:0 |reward:-0.0
# time:2 |load:0 |reward:-0.0
# time:3 |load:0 |reward:-0.0
# time:4 |load:1.75 |reward:-0.44
# time:5 |load:0 |reward:-0.0
# time:6 |load:0 |reward:-0.0
# time:7 |load:1.75 |reward:-0.25
#  2583/10000 [======>.......................] - ETA: 45s - reward: -3.1456time:8 |load:0 |reward:-0.0
# |needed:30 |battery:23.5
# time:1 |load:0 |reward:-0.0
# time:2 |load:0 |reward:-0.0
# time:3 |load:1.75 |reward:-0.58
# time:4 |load:0 |reward:-0.0
# time:5 |load:0 |reward:-0.0
#  2589/10000 [======>.......................] - ETA: 45s - reward: -3.1482time:6 |load:0 |reward:-0.0
# time:7 |load:0 |reward:-0.0
# time:8 |load:0 |reward:-0.0
# |needed:30 |battery:21.75
# time:1 |load:0 |reward:-0.0
# time:2 |load:1.75 |reward:-0.88
# time:3 |load:0 |reward:-0.0
# time:4 |load:1.75 |reward:-0.44
#  2596/10000 [======>.......................] - ETA: 45s - reward: -3.1498time:5 |load:0 |reward:-0.0
# time:6 |load:0 |reward:-0.0
# time:7 |load:0 |reward:-0.0
# time:8 |load:0 |reward:-0.0
# |needed:30 |battery:23.5
# time:1 |load:0 |reward:-0.0
# time:2 |load:0 |reward:-0.0
# time:3 |load:0 |reward:-0.0
#  2603/10000 [======>.......................] - ETA: 45s - reward: -3.1510time:4 |load:0 |reward:-0.0
# time:5 |load:0 |reward:-0.0
# time:6 |load:0 |reward:-0.0
# time:7 |load:0 |reward:-0.0
# time:8 |load:0 |reward:-0.0
# |needed:30 |battery:20
# time:1 |load:0 |reward:-0.0
# time:2 |load:0 |reward:-0.0
#  2610/10000 [======>.......................] - ETA: 45s - reward: -3.1521time:3 |load:0 |reward:-0.0
# time:4 |load:0 |reward:-0.0
# time:5 |load:0 |reward:-0.0
# time:6 |load:0 |reward:-0.0
# time:7 |load:0 |reward:-0.0
# time:8 |load:0 |reward:-0.0
# |needed:30 |battery:20
# time:1 |load:0 |reward:-0.0
#  2617/10000 [======>.......................] - ETA: 45s - reward: -3.1532time:2 |load:0 |reward:-0.0
# time:3 |load:0 |reward:-0.0
# time:4 |load:0 |reward:-0.0
# time:5 |load:0 |reward:-0.0
# time:6 |load:0 |reward:-0.0
# time:7 |load:1.75 |reward:-0.25
#  2623/10000 [======>.......................] - ETA: 45s - reward: -3.1461time:8 |load:0 |reward:-0.0
# |needed:30 |battery:21.75
# time:1 |load:0 |reward:-0.0
# time:2 |load:0 |reward:-0.0
# time:3 |load:0 |reward:-0.0
# time:4 |load:0 |reward:-0.0
# time:5 |load:0 |reward:-0.0
#  2629/10000 [======>.......................] - ETA: 45s - reward: -3.1484time:6 |load:0 |reward:-0.0
# time:7 |load:0 |reward:-0.0
# time:8 |load:0 |reward:-0.0
# |needed:30 |battery:20
# time:1 |load:0 |reward:-0.0
# time:2 |load:0 |reward:-0.0
# time:3 |load:0 |reward:-0.0
#  2635/10000 [======>.......................] - ETA: 45s - reward: -3.1508time:4 |load:0 |reward:-0.0
# time:5 |load:0 |reward:-0.0
# time:6 |load:0 |reward:-0.0
# time:7 |load:0 |reward:-0.0
# time:8 |load:0 |reward:-0.0
# |needed:30 |battery:20
# time:1 |load:0 |reward:-0.0
#  2641/10000 [======>.......................] - ETA: 45s - reward: -3.1531time:2 |load:0 |reward:-0.0
# time:3 |load:0 |reward:-0.0
# time:4 |load:1.75 |reward:-0.44
# time:5 |load:0 |reward:-0.0
# time:6 |load:0 |reward:-0.0
# time:7 |load:0 |reward:-0.0
# time:8 |load:0 |reward:-0.0
# |needed:30 |battery:21.75
# time:1 |load:0 |reward:-0.0
#  2649/10000 [======>.......................] - ETA: 45s - reward: -3.1531time:2 |load:1.75 |reward:-0.88
# time:3 |load:1.75 |reward:-0.58
# time:4 |load:0 |reward:-0.0
# time:5 |load:0 |reward:-0.0
# time:6 |load:0 |reward:-0.0
# time:7 |load:0 |reward:-0.0
# time:8 |load:0 |reward:-0.0
# |needed:30 |battery:23.5
# time:1 |load:0 |reward:-0.0
#  2657/10000 [======>.......................] - ETA: 45s - reward: -3.1536time:2 |load:0 |reward:-0.0
# time:3 |load:0 |reward:-0.0
# time:4 |load:1.75 |reward:-0.44
# time:5 |load:0 |reward:-0.0
# time:6 |load:0 |reward:-0.0
# time:7 |load:0 |reward:-0.0
# time:8 |load:0 |reward:-0.0
# |needed:30 |battery:21.75
# time:1 |load:0 |reward:-0.0
#  2665/10000 [======>.......................] - ETA: 45s - reward: -3.1537time:2 |load:0 |reward:-0.0
# time:3 |load:1.75 |reward:-0.58
# time:4 |load:0 |reward:-0.0
# time:5 |load:0 |reward:-0.0
# time:6 |load:0 |reward:-0.0
# time:7 |load:0 |reward:-0.0
# time:8 |load:0 |reward:-0.0
# |needed:30 |battery:21.75
# time:1 |load:0 |reward:-0.0
#  2673/10000 [=======>......................] - ETA: 45s - reward: -3.1538time:2 |load:0 |reward:-0.0
# time:3 |load:0 |reward:-0.0
# time:4 |load:0 |reward:-0.0
# time:5 |load:0 |reward:-0.0
# time:6 |load:0 |reward:-0.0
# time:7 |load:0 |reward:-0.0
# time:8 |load:0 |reward:-0.0
# |needed:30 |battery:20
# time:1 |load:0 |reward:-0.0
#  2681/10000 [=======>......................] - ETA: 45s - reward: -3.1537time:2 |load:1.75 |reward:-0.88
# time:3 |load:0 |reward:-0.0
# time:4 |load:0 |reward:-0.0
# time:5 |load:0 |reward:-0.0
# time:6 |load:0 |reward:-0.0
# time:7 |load:0 |reward:-0.0
# time:8 |load:0 |reward:-0.0
# |needed:30 |battery:21.75
# time:1 |load:0 |reward:-0.0
#  2689/10000 [=======>......................] - ETA: 45s - reward: -3.1540time:2 |load:0 |reward:-0.0
# time:3 |load:0 |reward:-0.0
# time:4 |load:0 |reward:-0.0
# time:5 |load:1.75 |reward:-0.35
# time:6 |load:1.75 |reward:-0.29
# time:7 |load:0 |reward:-0.0
# time:8 |load:0 |reward:-0.0
# |needed:30 |battery:23.5
# time:1 |load:0 |reward:-0.0
#  2697/10000 [=======>......................] - ETA: 45s - reward: -3.1541time:2 |load:0 |reward:-0.0
# time:3 |load:0 |reward:-0.0
# time:4 |load:0 |reward:-0.0
# time:5 |load:0 |reward:-0.0
# time:6 |load:0 |reward:-0.0
# time:7 |load:1.75 |reward:-0.25
# time:8 |load:0 |reward:-0.0
# |needed:30 |battery:21.75
#  2704/10000 [=======>......................] - ETA: 45s - reward: -3.1553time:1 |load:0 |reward:-0.0
# time:2 |load:0 |reward:-0.0
# time:3 |load:0 |reward:-0.0
# time:4 |load:0 |reward:-0.0
# time:5 |load:0 |reward:-0.0
#  2709/10000 [=======>......................] - ETA: 45s - reward: -3.1495time:6 |load:0 |reward:-0.0
# time:7 |load:0 |reward:-0.0
# time:8 |load:0 |reward:-0.0
# |needed:30 |battery:20
# time:1 |load:0 |reward:-0.0
# time:2 |load:0 |reward:-0.0
# time:3 |load:0 |reward:-0.0
# time:4 |load:0 |reward:-0.0
#  2716/10000 [=======>......................] - ETA: 45s - reward: -3.1506time:5 |load:0 |reward:-0.0
# time:6 |load:0 |reward:-0.0
# time:7 |load:0 |reward:-0.0
# time:8 |load:0 |reward:-0.0
# |needed:30 |battery:20
# time:1 |load:0 |reward:-0.0
# time:2 |load:0 |reward:-0.0
#  2722/10000 [=======>......................] - ETA: 45s - reward: -3.1528time:3 |load:0 |reward:-0.0
# time:4 |load:0 |reward:-0.0
# time:5 |load:0 |reward:-0.0
# time:6 |load:0 |reward:-0.0
# time:7 |load:0 |reward:-0.0
# time:8 |load:0 |reward:-0.0
# |needed:30 |battery:20
# time:1 |load:1.75 |reward:-1.75
#  2729/10000 [=======>......................] - ETA: 45s - reward: -3.1545time:2 |load:0 |reward:-0.0
# time:3 |load:0 |reward:-0.0
# time:4 |load:0 |reward:-0.0
# time:5 |load:1.75 |reward:-0.35
# time:6 |load:0 |reward:-0.0
# time:7 |load:0 |reward:-0.0
# time:8 |load:0 |reward:-0.0
# |needed:30 |battery:23.5
# time:1 |load:0 |reward:-0.0
#  2737/10000 [=======>......................] - ETA: 45s - reward: -3.1546time:2 |load:0 |reward:-0.0
# time:3 |load:0 |reward:-0.0
# time:4 |load:0 |reward:-0.0
# time:5 |load:0 |reward:-0.0
# time:6 |load:0 |reward:-0.0
# time:7 |load:0 |reward:-0.0
# time:8 |load:0 |reward:-0.0
# |needed:30 |battery:20
#  2744/10000 [=======>......................] - ETA: 45s - reward: -3.1556time:1 |load:0 |reward:-0.0
# time:2 |load:0 |reward:-0.0
# time:3 |load:0 |reward:-0.0
# time:4 |load:0 |reward:-0.0
# time:5 |load:0 |reward:-0.0
# time:6 |load:0 |reward:-0.0
# time:7 |load:0 |reward:-0.0
#  2751/10000 [=======>......................] - ETA: 45s - reward: -3.1476time:8 |load:0 |reward:-0.0
# |needed:30 |battery:20
# time:1 |load:1.75 |reward:-1.75
# time:2 |load:0 |reward:-0.0
# time:3 |load:0 |reward:-0.0
# time:4 |load:0 |reward:-0.0
# time:5 |load:0 |reward:-0.0
# time:6 |load:0 |reward:-0.0
#  2758/10000 [=======>......................] - ETA: 45s - reward: -3.1493time:7 |load:0 |reward:-0.0
# time:8 |load:0 |reward:-0.0
# |needed:30 |battery:21.75
# time:1 |load:0 |reward:-0.0
# time:2 |load:0 |reward:-0.0
# time:3 |load:0 |reward:-0.0
# time:4 |load:0 |reward:-0.0
# time:5 |load:0 |reward:-0.0
#  2765/10000 [=======>......................] - ETA: 45s - reward: -3.1504time:6 |load:0 |reward:-0.0
# time:7 |load:0 |reward:-0.0
# time:8 |load:0 |reward:-0.0
# |needed:30 |battery:20
# time:1 |load:0 |reward:-0.0
# time:2 |load:0 |reward:-0.0
# time:3 |load:1.75 |reward:-0.58
#  2771/10000 [=======>......................] - ETA: 45s - reward: -3.1528time:4 |load:0 |reward:-0.0
# time:5 |load:0 |reward:-0.0
# time:6 |load:0 |reward:-0.0
# time:7 |load:0 |reward:-0.0
# time:8 |load:0 |reward:-0.0
# |needed:30 |battery:21.75
# time:1 |load:0 |reward:-0.0
#  2777/10000 [=======>......................] - ETA: 45s - reward: -3.1550time:2 |load:0 |reward:-0.0
# time:3 |load:0 |reward:-0.0
# time:4 |load:0 |reward:-0.0
# time:5 |load:0 |reward:-0.0
# time:6 |load:0 |reward:-0.0
# time:7 |load:0 |reward:-0.0
#  2783/10000 [=======>......................] - ETA: 45s - reward: -3.1482time:8 |load:0 |reward:-0.0
# |needed:30 |battery:20
# time:1 |load:0 |reward:-0.0
# time:2 |load:0 |reward:-0.0
# time:3 |load:0 |reward:-0.0
# time:4 |load:0 |reward:-0.0
# time:5 |load:0 |reward:-0.0
# time:6 |load:0 |reward:-0.0
#  2790/10000 [=======>......................] - ETA: 45s - reward: -3.1492time:7 |load:0 |reward:-0.0
# time:8 |load:0 |reward:-0.0
# |needed:30 |battery:20
# time:1 |load:0 |reward:-0.0
# time:2 |load:0 |reward:-0.0
# time:3 |load:0 |reward:-0.0
# time:4 |load:0 |reward:-0.0
# time:5 |load:0 |reward:-0.0
#  2797/10000 [=======>......................] - ETA: 45s - reward: -3.1503time:6 |load:0 |reward:-0.0
# time:7 |load:0 |reward:-0.0
# time:8 |load:0 |reward:-0.0
# |needed:30 |battery:20
# time:1 |load:0 |reward:-0.0
# time:2 |load:0 |reward:-0.0
# time:3 |load:0 |reward:-0.0
#  2803/10000 [=======>......................] - ETA: 44s - reward: -3.1525time:4 |load:0 |reward:-0.0
# time:5 |load:0 |reward:-0.0
# time:6 |load:0 |reward:-0.0
# time:7 |load:0 |reward:-0.0
# time:8 |load:0 |reward:-0.0
# |needed:30 |battery:20
# time:1 |load:0 |reward:-0.0
# time:2 |load:0 |reward:-0.0
#  2810/10000 [=======>......................] - ETA: 44s - reward: -3.1535time:3 |load:0 |reward:-0.0
# time:4 |load:0 |reward:-0.0
# time:5 |load:0 |reward:-0.0
# time:6 |load:0 |reward:-0.0
# time:7 |load:0 |reward:-0.0
# time:8 |load:0 |reward:-0.0
# |needed:30 |battery:20
# time:1 |load:0 |reward:-0.0
#  2817/10000 [=======>......................] - ETA: 44s - reward: -3.1545time:2 |load:1.75 |reward:-0.88
# time:3 |load:0 |reward:-0.0
# time:4 |load:0 |reward:-0.0
# time:5 |load:0 |reward:-0.0
# time:6 |load:0 |reward:-0.0
# time:7 |load:0 |reward:-0.0
# time:8 |load:0 |reward:-0.0
# |needed:30 |battery:21.75
#  2824/10000 [=======>......................] - ETA: 44s - reward: -3.1559time:1 |load:0 |reward:-0.0
# time:2 |load:0 |reward:-0.0
# time:3 |load:0 |reward:-0.0
# time:4 |load:0 |reward:-0.0
# time:5 |load:0 |reward:-0.0
# time:6 |load:0 |reward:-0.0
#  2830/10000 [=======>......................] - ETA: 44s - reward: -3.1492time:7 |load:0 |reward:-0.0
# time:8 |load:0 |reward:-0.0
# |needed:30 |battery:20
# time:1 |load:0 |reward:-0.0
# time:2 |load:0 |reward:-0.0
# time:3 |load:0 |reward:-0.0
# time:4 |load:0 |reward:-0.0
# time:5 |load:0 |reward:-0.0
#  2837/10000 [=======>......................] - ETA: 44s - reward: -3.1502time:6 |load:0 |reward:-0.0
# time:7 |load:0 |reward:-0.0
# time:8 |load:0 |reward:-0.0
# |needed:30 |battery:20
# time:1 |load:0 |reward:-0.0
# time:2 |load:0 |reward:-0.0
# time:3 |load:0 |reward:-0.0
#  2843/10000 [=======>......................] - ETA: 44s - reward: -3.1524time:4 |load:0 |reward:-0.0
# time:5 |load:0 |reward:-0.0
# time:6 |load:0 |reward:-0.0
# time:7 |load:0 |reward:-0.0
# time:8 |load:0 |reward:-0.0
# |needed:30 |battery:20
# time:1 |load:0 |reward:-0.0
# time:2 |load:0 |reward:-0.0
#  2850/10000 [=======>......................] - ETA: 44s - reward: -3.1534time:3 |load:0 |reward:-0.0
# time:4 |load:0 |reward:-0.0
# time:5 |load:0 |reward:-0.0
# time:6 |load:0 |reward:-0.0
# time:7 |load:0 |reward:-0.0
# time:8 |load:0 |reward:-0.0
# |needed:30 |battery:20
# time:1 |load:0 |reward:-0.0
#  2857/10000 [=======>......................] - ETA: 44s - reward: -3.1544time:2 |load:0 |reward:-0.0
# time:3 |load:0 |reward:-0.0
# time:4 |load:0 |reward:-0.0
# time:5 |load:0 |reward:-0.0
# time:6 |load:0 |reward:-0.0
# time:7 |load:1.75 |reward:-0.25
# time:8 |load:0 |reward:-0.0
# |needed:30 |battery:21.75
# time:1 |load:0 |reward:-0.0
#  2865/10000 [=======>......................] - ETA: 44s - reward: -3.1544time:2 |load:0 |reward:-0.0
# time:3 |load:0 |reward:-0.0
# time:4 |load:0 |reward:-0.0
# time:5 |load:1.75 |reward:-0.35
# time:6 |load:0 |reward:-0.0
# time:7 |load:0 |reward:-0.0
# time:8 |load:0 |reward:-0.0
# |needed:30 |battery:21.75
#  2872/10000 [=======>......................] - ETA: 44s - reward: -3.1556time:1 |load:0 |reward:-0.0
# time:2 |load:0 |reward:-0.0
# time:3 |load:0 |reward:-0.0
# time:4 |load:0 |reward:-0.0
# time:5 |load:0 |reward:-0.0
# time:6 |load:0 |reward:-0.0
#  2878/10000 [=======>......................] - ETA: 44s - reward: -3.1490time:7 |load:0 |reward:-0.0
# time:8 |load:0 |reward:-0.0
# |needed:30 |battery:20
# time:1 |load:0 |reward:-0.0
# time:2 |load:1.75 |reward:-0.88
# time:3 |load:1.75 |reward:-0.58
# time:4 |load:0 |reward:-0.0
# time:5 |load:0 |reward:-0.0
#  2885/10000 [=======>......................] - ETA: 44s - reward: -3.1505time:6 |load:0 |reward:-0.0
# time:7 |load:0 |reward:-0.0
# time:8 |load:0 |reward:-0.0
# |needed:30 |battery:23.5
# time:1 |load:0 |reward:-0.0
# time:2 |load:0 |reward:-0.0
# time:3 |load:0 |reward:-0.0
# time:4 |load:0 |reward:-0.0
#  2892/10000 [=======>......................] - ETA: 44s - reward: -3.1516time:5 |load:0 |reward:-0.0
# time:6 |load:1.75 |reward:-0.29
# time:7 |load:0 |reward:-0.0
# time:8 |load:0 |reward:-0.0
# |needed:30 |battery:21.75
# time:1 |load:0 |reward:-0.0
# time:2 |load:0 |reward:-0.0
# time:3 |load:0 |reward:-0.0
#  2899/10000 [=======>......................] - ETA: 44s - reward: -3.1527time:4 |load:0 |reward:-0.0
# time:5 |load:0 |reward:-0.0
# time:6 |load:0 |reward:-0.0
# time:7 |load:0 |reward:-0.0
# time:8 |load:0 |reward:-0.0
# |needed:30 |battery:20
# time:1 |load:0 |reward:-0.0
# time:2 |load:0 |reward:-0.0
#  2906/10000 [=======>......................] - ETA: 44s - reward: -3.1537time:3 |load:0 |reward:-0.0
# time:4 |load:0 |reward:-0.0
# time:5 |load:0 |reward:-0.0
# time:6 |load:0 |reward:-0.0
# time:7 |load:0 |reward:-0.0
# time:8 |load:0 |reward:-0.0
# |needed:30 |battery:20
# time:1 |load:0 |reward:-0.0
#  2913/10000 [=======>......................] - ETA: 44s - reward: -3.1547time:2 |load:0 |reward:-0.0
# time:3 |load:0 |reward:-0.0
# time:4 |load:0 |reward:-0.0
# time:5 |load:0 |reward:-0.0
# time:6 |load:1.75 |reward:-0.29
# time:7 |load:0 |reward:-0.0
#  2919/10000 [=======>......................] - ETA: 44s - reward: -3.1483time:8 |load:0 |reward:-0.0
# |needed:30 |battery:21.75
# time:1 |load:0 |reward:-0.0
# time:2 |load:0 |reward:-0.0
# time:3 |load:0 |reward:-0.0
# time:4 |load:0 |reward:-0.0
# time:5 |load:0 |reward:-0.0
# time:6 |load:0 |reward:-0.0
#  2926/10000 [=======>......................] - ETA: 44s - reward: -3.1493done, took 18.587 seconds

# %%
# Testing the agent on the simple Environment
results = dqn.test(simpleEnv, nb_episodes=2, visualize=False)
print(np.mean(results.history['episode_reward']))
# Out:
# Testing for 2 episodes ...
# time:1 |load:0 |reward:-0.0
# time:2 |load:0 |reward:-0.0
# time:3 |load:0 |reward:-0.0
# time:4 |load:0 |reward:-0.0
# time:5 |load:0 |reward:-0.0
# time:6 |load:0 |reward:-0.0
# time:7 |load:0 |reward:-0.0
# time:8 |load:0 |reward:-0.0
# |needed:30 |battery:20
# Episode 1: reward: -25.000, steps: 8
# time:1 |load:0 |reward:-0.0
# time:2 |load:0 |reward:-0.0
# time:3 |load:0 |reward:-0.0
# time:4 |load:0 |reward:-0.0
# time:5 |load:0 |reward:-0.0
# time:6 |load:0 |reward:-0.0
# time:7 |load:0 |reward:-0.0
# time:8 |load:0 |reward:-0.0
# |needed:30 |battery:20
# Episode 2: reward: -25.000, steps: 8
# -25.0

# %% [markdown]
# ## Environment from the Exercise

# %%
import tensorflow
print("Num GPUs Available: ", len(tensorflow.config.experimental.list_physical_devices('GPU')))
# Out:
# Num GPUs Available:  0

# %%
tensorflow.config.experimental.list_physical_devices('GPU')
# Out:
# []

# %%
class Environment(Env):
    def __init__(self):
        #Possible Actions for charging zero, low, medium to high
        self.action_space = Discrete(4)
        #Vehicle's battery: 69KWh; Timeframe 2p.m. to 4p.m.: 8x 15 minute intervals
        self.battery_limit = 69
        self.observation_space = np.array([Box(low=np.array([0]), high = np.array([self.battery_limit])), Box(low=np.array([0]), high = np.array([8]))])
        # Starting at 2p.m.: 0 (going to 3:45p.m.: 7)
        self.time = 0
        self.time_delta =  15/60
        # 20 KWh loaded battery at initialization
        #self.battery = 10 + random.randint(-10,10)
        self.battery = 21
        # our state consisting of battery status and time
        self.state = np.array([self.battery, self.time])


    def step(self, action):
        # Setting loading interval +1/8 /--> +15/120 minutes
        self.time += 1
        self.state[1] = self.time

        # Seting new battery state
        #zero
        load = 0
        if action == 2:
            #low
            load += 7 * self.time_delta
            # loading until max capacity 
            if self.battery + load > self.battery_limit:
                diff = self.battery_limit - self.battery
                load = diff / self.time_delta
        if action == 3:
            #medium
            load += 14 * self.time_delta
            # loading until max capacity 
            if self.battery + load > self.battery_limit:
                diff = self.battery_limit - self.battery
                load = diff / self.time_delta
        if action == 4:
            #high
            load += 22 * self.time_delta
            # loading until max capacity 
            if self.battery + load > self.battery_limit:
                diff = self.battery_limit - self.battery
                load = diff / self.time_delta
        # load multiplied by 15 min to get the 
        self.battery += load
        self.state[0] = self.battery

        # Cost function
        reward = self.time * math.exp(load) * (-1)
        # Because e^0 = 1
        if action == 0:
            reward = 0

        
       # print("time:" + str(self.time) + " |load:" + str(load) + " |reward:" + str(round(reward, 2)))

        #Checking if 2 Hours are done
        if self.time >= 8:
            #Demand is a random value following a normal distribution (e.g., 𝜇= 30 kWh, 𝜎 = 5 kWh)
            kwh_needed = np.random.normal(loc=30, scale=5)
            #print("|needed:" + str(round(kwh_needed, 2))+" |battery:" + str(round(self.battery, 2)))
            # The agent’s goal is to avoid running out of energy (with a very high penalty) 
            if kwh_needed > self.battery:
                #print("NO BATTERY")
                reward -= 10000
            done = True
        else:
            done = False

        info = {}

        # Returning the step information
        return self.state, reward, done, info
    
    def reset(self):
        # Starting at 2p.m.: 0 (going to 3:45p.m.: 7)
        self.time = 0
        # 20 KWh loaded battery at initialization
        #self.battery = 10 + random.randint(-10,10)
        self.battery = 21
        # our state consisting of battery status and time
        self.state = np.array([self.battery, self.time])
        return self.state

# %%
class EnvironmentPrint(Env):
    def __init__(self):
        #Possible Actions for charging zero, low, medium to high
        self.action_space = Discrete(4)
        #Vehicle's battery: 69KWh; Timeframe 2p.m. to 4p.m.: 8x 15 minute intervals
        self.battery_limit = 69
        self.observation_space = np.array([Box(low=np.array([0]), high = np.array([self.battery_limit])), Box(low=np.array([0]), high = np.array([8]))])
        # Starting at 2p.m.: 0 (going to 3:45p.m.: 7)
        self.time = 0
        self.time_delta =  15/60
        # 20 KWh loaded battery at initialization
        #self.battery = 10 + random.randint(-10,10)
        self.battery = 21
        # our state consisting of battery status and time
        self.state = np.array([self.battery, self.time])


    def step(self, action):
        # Setting loading interval +1/8 /--> +15/120 minutes
        self.time += 1
        self.state[1] = self.time

        # Seting new battery state
        #zero
        load = 0
        if action == 2:
            #low
            load += 7 * self.time_delta
            # loading until max capacity 
            if self.battery + load > self.battery_limit:
                diff = self.battery_limit - self.battery
                load = diff / self.time_delta
        if action == 3:
            #medium
            load += 14 * self.time_delta
            # loading until max capacity 
            if self.battery + load > self.battery_limit:
                diff = self.battery_limit - self.battery
                load = diff / self.time_delta
        if action == 4:
            #high
            load += 22 * self.time_delta
            # loading until max capacity 
            if self.battery + load > self.battery_limit:
                diff = self.battery_limit - self.battery
                load = diff / self.time_delta
        # load multiplied by 15 min to get the 
        self.battery += load
        self.state[0] = self.battery

        # Cost function
        reward = self.time * math.exp(load) * (-1)
        # Because e^0 = 1
        if action == 0:
            reward = 0

        
        print("time:" + str(self.time) + " |load:" + str(load) + " |reward:" + str(round(reward, 2)))

        #Checking if 2 Hours are done
        if self.time >= 8:
            #Demand is a random value following a normal distribution (e.g., 𝜇= 30 kWh, 𝜎 = 5 kWh)
            kwh_needed = np.random.normal(loc=30, scale=5)
            print("|needed:" + str(round(kwh_needed, 2))+" |battery:" + str(round(self.battery, 2)))
            # The agent’s goal is to avoid running out of energy (with a very high penalty) 
            if kwh_needed > self.battery:
                #print("NO BATTERY")
                reward -= 10000
            done = True
        else:
            done = False

        info = {}

        # Returning the step information
        return self.state, reward, done, info
    
    def reset(self):
        # Starting at 2p.m.: 0 (going to 3:45p.m.: 7)
        self.time = 0
        # 20 KWh loaded battery at initialization
        #self.battery = 10 + random.randint(-10,10)
        self.battery = 21
        # our state consisting of battery status and time
        self.state = np.array([self.battery, self.time])
        return self.state

# %%
env = Environment()

# %%
envPrint = EnvironmentPrint()

# %%
# Destilling Information from hour model
states = env.observation_space.shape
actions = env.action_space.n
print("Actions: " + str(actions) + " | States: " + str(states))
# Out:
# Actions: 4 | States: (2,)

# %%
# Defining our model
model = Sequential()    
model.add(Flatten(input_shape=(1,2)))
#model.add(Dense(32, activation='relu'))
#model.add(Dense(16, activation='relu'))
model.add(Dense(8, activation='relu'))
model.add(Dense(4, activation='relu'))
model.add(Dense(actions, activation='linear'))
model.summary()
# Out:
# Model: "sequential_11"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  flatten_11 (Flatten)        (None, 2)                 0
#
#  dense_39 (Dense)            (None, 8)                 24
#
#  dense_40 (Dense)            (None, 4)                 36
#
#  dense_41 (Dense)            (None, 4)                 20
#
# =================================================================
# Total params: 80
# Trainable params: 80
# Non-trainable params: 0
# _________________________________________________________________

# %%
# Defining and training of Deep Q-Network Agent
policy = BoltzmannQPolicy()
memory = SequentialMemory(limit=10000*2, window_length=1)
dqn = DQNAgent(model=model, memory=memory, policy=policy, nb_actions=actions, nb_steps_warmup=10000*1, target_model_update=1e-2)
dqn.compile(Adam(learning_rate=0.05), metrics=['mae'])
dqn.fit(env, nb_steps=10000*4, visualize=False, verbose=1)
# Out:
# Training for 40000 steps ...
# Interval 1 (0 steps performed)
# 10000/10000 [==============================] - 14s 1ms/step - reward: -1216.5327
# 1250 episodes - episode_reward: -9732.262 [-10292.924, -28.000]
#
# Interval 2 (10000 steps performed)
# 10000/10000 [==============================] - 108s 11ms/step - reward: -333.6886
# 1250 episodes - episode_reward: -2669.509 [-10895.529, 0.000] - loss: 4445999.493 - mae: 330.824 - mean_q: -92.091
#
# Interval 3 (20000 steps performed)
# 10000/10000 [==============================] - 104s 10ms/step - reward: -244.4449
# 1250 episodes - episode_reward: -1955.559 [-10784.674, -5.755] - loss: 2021754.625 - mae: 437.468 - mean_q: -346.918
#
# Interval 4 (30000 steps performed)
# 10000/10000 [==============================] - 106s 11ms/step - reward: -526.1539
# done, took 331.552 seconds

# %%
# Testing the agent on the simple Environment
results = dqn.test(envPrint, nb_episodes=20, visualize=False)
print(np.mean(results.history['episode_reward']))
# Out:
# Testing for 20 episodes ...
# time:1 |load:1.75 |reward:-5.75
# time:2 |load:1.75 |reward:-11.51
# time:3 |load:1.75 |reward:-17.26
# time:4 |load:1.75 |reward:-23.02
# time:5 |load:1.75 |reward:-28.77
# time:6 |load:1.75 |reward:-34.53
# time:7 |load:1.75 |reward:-40.28
# time:8 |load:1.75 |reward:-46.04
# |needed:27.46 |battery:35.0
# Episode 1: reward: -207.166, steps: 8
# time:1 |load:1.75 |reward:-5.75
# time:2 |load:1.75 |reward:-11.51
# time:3 |load:1.75 |reward:-17.26
# time:4 |load:1.75 |reward:-23.02
# time:5 |load:1.75 |reward:-28.77
# time:6 |load:1.75 |reward:-34.53
# time:7 |load:1.75 |reward:-40.28
# time:8 |load:1.75 |reward:-46.04
# |needed:26.09 |battery:35.0
# Episode 2: reward: -207.166, steps: 8
# time:1 |load:1.75 |reward:-5.75
# time:2 |load:1.75 |reward:-11.51
# time:3 |load:1.75 |reward:-17.26
# time:4 |load:1.75 |reward:-23.02
# time:5 |load:1.75 |reward:-28.77
# time:6 |load:1.75 |reward:-34.53
# time:7 |load:1.75 |reward:-40.28
# time:8 |load:1.75 |reward:-46.04
# |needed:29.16 |battery:35.0
# Episode 3: reward: -207.166, steps: 8
# time:1 |load:1.75 |reward:-5.75
# time:2 |load:1.75 |reward:-11.51
# time:3 |load:1.75 |reward:-17.26
# time:4 |load:1.75 |reward:-23.02
# time:5 |load:1.75 |reward:-28.77
# time:6 |load:1.75 |reward:-34.53
# time:7 |load:1.75 |reward:-40.28
# time:8 |load:1.75 |reward:-46.04
# |needed:30.09 |battery:35.0
# Episode 4: reward: -207.166, steps: 8
# time:1 |load:1.75 |reward:-5.75
# time:2 |load:1.75 |reward:-11.51
# time:3 |load:1.75 |reward:-17.26
# time:4 |load:1.75 |reward:-23.02
# time:5 |load:1.75 |reward:-28.77
# time:6 |load:1.75 |reward:-34.53
# time:7 |load:1.75 |reward:-40.28
# time:8 |load:1.75 |reward:-46.04
# |needed:37.94 |battery:35.0
# Episode 5: reward: -10207.166, steps: 8
# time:1 |load:1.75 |reward:-5.75
# time:2 |load:1.75 |reward:-11.51
# time:3 |load:1.75 |reward:-17.26
# time:4 |load:1.75 |reward:-23.02
# time:5 |load:1.75 |reward:-28.77
# time:6 |load:1.75 |reward:-34.53
# time:7 |load:1.75 |reward:-40.28
# time:8 |load:1.75 |reward:-46.04
# |needed:30.99 |battery:35.0
# Episode 6: reward: -207.166, steps: 8
# time:1 |load:1.75 |reward:-5.75
# time:2 |load:1.75 |reward:-11.51
# time:3 |load:1.75 |reward:-17.26
# time:4 |load:1.75 |reward:-23.02
# time:5 |load:1.75 |reward:-28.77
# time:6 |load:1.75 |reward:-34.53
# time:7 |load:1.75 |reward:-40.28
# time:8 |load:1.75 |reward:-46.04
# |needed:29.18 |battery:35.0
# Episode 7: reward: -207.166, steps: 8
# time:1 |load:1.75 |reward:-5.75
# time:2 |load:1.75 |reward:-11.51
# time:3 |load:1.75 |reward:-17.26
# time:4 |load:1.75 |reward:-23.02
# time:5 |load:1.75 |reward:-28.77
# time:6 |load:1.75 |reward:-34.53
# time:7 |load:1.75 |reward:-40.28
# time:8 |load:1.75 |reward:-46.04
# |needed:27.28 |battery:35.0
# Episode 8: reward: -207.166, steps: 8
# time:1 |load:1.75 |reward:-5.75
# time:2 |load:1.75 |reward:-11.51
# time:3 |load:1.75 |reward:-17.26
# time:4 |load:1.75 |reward:-23.02
# time:5 |load:1.75 |reward:-28.77
# time:6 |load:1.75 |reward:-34.53
# time:7 |load:1.75 |reward:-40.28
# time:8 |load:1.75 |reward:-46.04
# |needed:33.64 |battery:35.0
# Episode 9: reward: -207.166, steps: 8
# time:1 |load:1.75 |reward:-5.75
# time:2 |load:1.75 |reward:-11.51
# time:3 |load:1.75 |reward:-17.26
# time:4 |load:1.75 |reward:-23.02
# time:5 |load:1.75 |reward:-28.77
# time:6 |load:1.75 |reward:-34.53
# time:7 |load:1.75 |reward:-40.28
# time:8 |load:1.75 |reward:-46.04
# |needed:32.46 |battery:35.0
# Episode 10: reward: -207.166, steps: 8
# time:1 |load:1.75 |reward:-5.75
# time:2 |load:1.75 |reward:-11.51
# time:3 |load:1.75 |reward:-17.26
# time:4 |load:1.75 |reward:-23.02
# time:5 |load:1.75 |reward:-28.77
# time:6 |load:1.75 |reward:-34.53
# time:7 |load:1.75 |reward:-40.28
# time:8 |load:1.75 |reward:-46.04
# |needed:26.91 |battery:35.0
# Episode 11: reward: -207.166, steps: 8
# time:1 |load:1.75 |reward:-5.75
# time:2 |load:1.75 |reward:-11.51
# time:3 |load:1.75 |reward:-17.26
# time:4 |load:1.75 |reward:-23.02
# time:5 |load:1.75 |reward:-28.77
# time:6 |load:1.75 |reward:-34.53
# time:7 |load:1.75 |reward:-40.28
# time:8 |load:1.75 |reward:-46.04
# |needed:40.58 |battery:35.0
# Episode 12: reward: -10207.166, steps: 8
# time:1 |load:1.75 |reward:-5.75
# time:2 |load:1.75 |reward:-11.51
# time:3 |load:1.75 |reward:-17.26
# time:4 |load:1.75 |reward:-23.02
# time:5 |load:1.75 |reward:-28.77
# time:6 |load:1.75 |reward:-34.53
# time:7 |load:1.75 |reward:-40.28
# time:8 |load:1.75 |reward:-46.04
# |needed:28.52 |battery:35.0
# Episode 13: reward: -207.166, steps: 8
# time:1 |load:1.75 |reward:-5.75
# time:2 |load:1.75 |reward:-11.51
# time:3 |load:1.75 |reward:-17.26
# time:4 |load:1.75 |reward:-23.02
# time:5 |load:1.75 |reward:-28.77
# time:6 |load:1.75 |reward:-34.53
# time:7 |load:1.75 |reward:-40.28
# time:8 |load:1.75 |reward:-46.04
# |needed:28.35 |battery:35.0
# Episode 14: reward: -207.166, steps: 8
# time:1 |load:1.75 |reward:-5.75
# time:2 |load:1.75 |reward:-11.51
# time:3 |load:1.75 |reward:-17.26
# time:4 |load:1.75 |reward:-23.02
# time:5 |load:1.75 |reward:-28.77
# time:6 |load:1.75 |reward:-34.53
# time:7 |load:1.75 |reward:-40.28
# time:8 |load:1.75 |reward:-46.04
# |needed:33.53 |battery:35.0
# Episode 15: reward: -207.166, steps: 8
# time:1 |load:1.75 |reward:-5.75
# time:2 |load:1.75 |reward:-11.51
# time:3 |load:1.75 |reward:-17.26
# time:4 |load:1.75 |reward:-23.02
# time:5 |load:1.75 |reward:-28.77
# time:6 |load:1.75 |reward:-34.53
# time:7 |load:1.75 |reward:-40.28
# time:8 |load:1.75 |reward:-46.04
# |needed:22.17 |battery:35.0
# Episode 16: reward: -207.166, steps: 8
# time:1 |load:1.75 |reward:-5.75
# time:2 |load:1.75 |reward:-11.51
# time:3 |load:1.75 |reward:-17.26
# time:4 |load:1.75 |reward:-23.02
# time:5 |load:1.75 |reward:-28.77
# time:6 |load:1.75 |reward:-34.53
# time:7 |load:1.75 |reward:-40.28
# time:8 |load:1.75 |reward:-46.04
# |needed:24.97 |battery:35.0
# Episode 17: reward: -207.166, steps: 8
# time:1 |load:1.75 |reward:-5.75
# time:2 |load:1.75 |reward:-11.51
# time:3 |load:1.75 |reward:-17.26
# time:4 |load:1.75 |reward:-23.02
# time:5 |load:1.75 |reward:-28.77
# time:6 |load:1.75 |reward:-34.53
# time:7 |load:1.75 |reward:-40.28
# time:8 |load:1.75 |reward:-46.04
# |needed:31.16 |battery:35.0
# Episode 18: reward: -207.166, steps: 8
# time:1 |load:1.75 |reward:-5.75
# time:2 |load:1.75 |reward:-11.51
# time:3 |load:1.75 |reward:-17.26
# time:4 |load:1.75 |reward:-23.02
# time:5 |load:1.75 |reward:-28.77
# time:6 |load:1.75 |reward:-34.53
# time:7 |load:1.75 |reward:-40.28
# time:8 |load:1.75 |reward:-46.04
# |needed:30.49 |battery:35.0
# Episode 19: reward: -207.166, steps: 8
# time:1 |load:1.75 |reward:-5.75
# time:2 |load:1.75 |reward:-11.51
# time:3 |load:1.75 |reward:-17.26
# time:4 |load:1.75 |reward:-23.02
# time:5 |load:1.75 |reward:-28.77
# time:6 |load:1.75 |reward:-34.53
# time:7 |load:1.75 |reward:-40.28
# time:8 |load:1.75 |reward:-46.04
# |needed:27.99 |battery:35.0
# Episode 20: reward: -207.166, steps: 8
# -1207.1656963362066

# %%
1* math.exp(22/4) * (-1)
# Out:
# -244.69193226422038

# %%
(1* math.exp(14/4) + 2* math.exp(14/4) + 3* math.exp(14/4) + 4* math.exp(14/4) + 5* math.exp(14/4) + 6* math.exp(14/4)  + 7* math.exp(14/4) + 8* math.exp(14/4))*(-1)
# Out:
# -1192.1562705129234

# %%
(14*8)/4
# Out:
# 28.0

# %%
(1* math.exp(22/4) + 2* math.exp(22/4) + 3* math.exp(14/4) + 4* math.exp(14/4) + 5* math.exp(14/4) + 6* math.exp(14/4)  + 7* math.exp(14/4))*(-1)
# Out:
# -1561.9620957599689

# %%
(14*5+22*2)/4
# Out:
# 28.5

# %%
1.75*8
# Out:
# 14.0

# %%
1* math.exp(22/4) * (-1) + 2* math.exp(22/4) * (-1) + 4* math.exp(14/4) * (-1)
# Out:
# -866.5376046274304

# %%
np.random.normal(loc=30, scale=5)
# Out:
# 38.50503978316501

# %%
3.5*8
# Out:
# 28.0

# %%
# Out:
# 2.8

# %%
28*4/22
# Out:
# 5.090909090909091

# %%
math.exp(22/4)*(-1)*(1+2+3+4+5+6+7+8)
# Out:
# -8808.909561511933
